# %%
import os
os.environ["OMP_NUM_THREADS"] = "1" # export OMP_NUM_THREADS=1
os.environ["OPENBLAS_NUM_THREADS"] = "1" # export OPENBLAS_NUM_THREADS=1
os.environ["MKL_NUM_THREADS"] = "1" # export MKL_NUM_THREADS=1
os.environ["VECLIB_MAXIMUM_THREADS"] = "1" # export VECLIB_MAXIMUM_THREADS=1
os.environ["NUMEXPR_NUM_THREADS"] = "1" # export NUMEXPR_NUM_THREADS=1
os.environ["CUDA_VISIBLE_DEVICES"]= '3'

import numpy as np
import matplotlib.pyplot as plt
import multielec_src.fitting as fitting
import multielec_src.multielec_utils as mutils
from scipy.io import loadmat
import multiprocessing as mp
import statsmodels.api as sm
from copy import deepcopy, copy
import visionloader as vl
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def sample_spikes(p_true, t):
    p_true, t = np.array(p_true), np.array(t).astype(int)
    
    p_empirical = []
    for i in range(len(p_true)):
        if t[i] == 0:
            p_empirical += [0.5]
        
        else:
            p_empirical += [np.mean(np.random.choice(np.array([0, 1]), 
                                                 p=np.array([1-p_true[i], p_true[i]]), 
                                                 size=t[i]))]
        
    p_empirical_array = np.array(p_empirical)

    return p_empirical_array

# %%
def sample_spikes_array(true_probs, trials, NUM_THREADS=24):

    input_list = []
    for i in range(len(true_probs)):
        for j in range(len(true_probs[i])):
            input_list += [(true_probs[i][j], trials[j])]
            
    pool = mp.Pool(processes=NUM_THREADS)
    results = pool.starmap_async(sample_spikes, input_list)
    mp_output = results.get()
    pool.close()

    return np.array(mp_output).reshape(true_probs.shape)

# %%
def get_performance_array(true_params, curr_probs, true_probs):
    
    error = 0
    cnt = 0
    for i in range(len(true_params)):
        for j in range(len(true_params[i])):
            if type(true_params[i][j]) != int:
                error += np.sqrt(np.sum((curr_probs[i][j] - true_probs[i][j])**2) / len(true_probs[i][j]))
                cnt += 1

    return error / cnt

# %%
NUM_CELLS = 120
NUM_PATTERNS = 80
ms = [1, 2, 3, 4]
cell_positions = np.random.choice(NUM_PATTERNS, size=NUM_CELLS, replace=True)
bias_mean = -8
bias_var = 2
slope_var = 5

amps_scan = np.array([np.array(np.meshgrid(np.linspace(-2, 2, 21), 
                                np.linspace(-2, 2, 21),
                                np.linspace(-2, 2, 21))).T.reshape(-1,3)] * NUM_PATTERNS)

params_true = np.zeros((NUM_CELLS, NUM_PATTERNS), dtype=object)
probs_true_scan = np.zeros((NUM_CELLS, NUM_PATTERNS, amps_scan.shape[1]))

for i in range(len(cell_positions)):
    m = np.random.choice(np.array(ms))
    j = cell_positions[i]
    
    params = np.zeros((m, amps_scan[j].shape[1]+1))
    for l in range(m):
        params[l, :] = np.random.normal(np.random.choice([-5, 5]), slope_var, size=amps_scan[j].shape[1]+1)

    params[:, 0] = np.random.normal(bias_mean, bias_var, len(params[:, 0]))
    params_true[i][j] = params

for i in range(len(probs_true_scan)):
    for j in range(len(probs_true_scan[i])):
        if type(params_true[i][j]) != int:
            probs_true_scan[i][j] = fitting.sigmoidND_nonlinear(
                                    sm.add_constant(amps_scan[j], has_constant='add'), 
                                    params_true[i][j])
        else:
            probs_true_scan[i][j] = np.zeros(amps_scan.shape[1])

# %%
# CHECK DATASET IF NEEDED
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(probs_true_scan)):
    for j in range(len(probs_true_scan[i])):
        if type(params_true[i][j]) != int:

            print(params_true[i][j])
            
            fig = plt.figure(0)
            fig.clear()
            ax = Axes3D(fig, auto_add_to_figure=False)
            fig.add_axes(ax)
            plt.xlabel(r'$I_1$ ($\mu$A)', fontsize=16)
            plt.ylabel(r'$I_2$ ($\mu$A)', fontsize=16)
            plt.xlim(-1.8, 1.8)
            plt.ylim(-1.8, 1.8)
            ax.set_zlim(-1.8, 1.8)
            ax.set_zlabel(r'$I_3$ ($\mu$A)', fontsize=16)

            scat = ax.scatter(amps_scan[j][:, 0], 
                              amps_scan[j][:, 1],
                              amps_scan[j][:, 2], marker='o', 
                              c=probs_true_scan[i][j], s=20, alpha=0.8, vmin=0, vmax=1)
            plt.show()

            input()
# Out:
# [[-9.43505194  5.58789145  9.68852402  5.04733018]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Volumes/Lab/Users/praful/multielectrode/scripts/jupyter_notebooks/fisher_sampling_testing_multielec_fakedata_01.ipynb Cell 6 in <cell line: 4>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bpeggyo/Volumes/Lab/Users/praful/multielectrode/scripts/jupyter_notebooks/fisher_sampling_testing_multielec_fakedata_01.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> scat = ax.scatter(amps_scan[j][:, 0],
#      <a href='vscode-notebook-cell://ssh-remote%2Bpeggyo/Volumes/Lab/Users/praful/multielectrode/scripts/jupyter_notebooks/fisher_sampling_testing_multielec_fakedata_01.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>                   amps_scan[j][:, 1],
#      <a href='vscode-notebook-cell://ssh-remote%2Bpeggyo/Volumes/Lab/Users/praful/multielectrode/scripts/jupyter_notebooks/fisher_sampling_testing_multielec_fakedata_01.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>                   amps_scan[j][:, 2], marker='o',
#      <a href='vscode-notebook-cell://ssh-remote%2Bpeggyo/Volumes/Lab/Users/praful/multielectrode/scripts/jupyter_notebooks/fisher_sampling_testing_multielec_fakedata_01.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>                   c=probs_true_scan[i][j], s=20, alpha=0.8, vmin=0, vmax=1)
#      <a href='vscode-notebook-cell://ssh-remote%2Bpeggyo/Volumes/Lab/Users/praful/multielectrode/scripts/jupyter_notebooks/fisher_sampling_testing_multielec_fakedata_01.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> plt.show()
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bpeggyo/Volumes/Lab/Users/praful/multielectrode/scripts/jupyter_notebooks/fisher_sampling_testing_multielec_fakedata_01.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> input()
#
# File /Volumes/Lab/Development/miniconda-peggyo/envs/pvasi39/lib/python3.9/site-packages/ipykernel/kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File /Volumes/Lab/Development/miniconda-peggyo/envs/pvasi39/lib/python3.9/site-packages/ipykernel/kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# total_budget = 50000
num_iters = 5

T_prev = np.zeros((amps_scan.shape[0], amps_scan.shape[1]), dtype=float)
budget = T_prev.shape[0] * T_prev.shape[1] * 0.5 #int(total_budget / num_iters)
reg = None # 20, 50
T_step_size = 0.05 # 0.05, 0.01
T_n_steps = 5000    # 5000

init_trials = 10
init_amps = 500
ms = [1, 2, 3, 4]
disambiguate = False
verbose = True
R2_cutoff = 0
prob_low = 1 / init_trials

for i in range(len(T_prev)):
    init_inds = np.random.choice(np.arange(len(T_prev[i]), dtype=int), size=init_amps,
                                 replace=False)
    T_prev[i][init_inds] = init_trials

# T_prev[:, np.where(np.count_nonzero(amps_scan[0], axis=1) <= 1)[0]] = init_trials
T_prev_uniform = deepcopy(T_prev)

probs_empirical = sample_spikes_array(probs_true_scan, T_prev, NUM_THREADS=24)
probs_empirical_uniform = deepcopy(probs_empirical)

performances = []
performances_uniform = []
num_samples = []
num_samples_uniform = []

iter_cnt = 0
while True:
    if iter_cnt == 0:
        T_new, w_inits_array, t_final, probs_curr, params_curr = fitting.fisher_sampling_1elec(
                                        probs_empirical, 
                                        T_prev, amps_scan,
                                        T_step_size=T_step_size,
                                        T_n_steps=T_n_steps,
                                        verbose=verbose, budget=budget, ms=ms, reg=reg,
                                        return_probs=True,
                                        disambiguate=disambiguate,
                                        R2_cutoff=R2_cutoff,
                                        min_prob=prob_low)

        performance = get_performance_array(params_true, probs_curr, probs_true_scan)
        performance_uniform = performance

        w_inits_array_uniform = deepcopy(w_inits_array)
        
    else:
        T_new, w_inits_array, t_final, probs_curr, params_curr = fitting.fisher_sampling_1elec(
                                        probs_empirical, 
                                        T_prev, amps_scan,
                                        T_step_size=T_step_size,
                                        T_n_steps=T_n_steps,
                                        verbose=verbose, budget=budget, ms=ms, reg=reg,
                                        return_probs=True,
                                        # t_final=t_final,
                                        w_inits_array=w_inits_array,
                                        disambiguate=disambiguate,
                                        R2_cutoff=R2_cutoff,
                                        min_prob=prob_low)
        
        performance = get_performance_array(params_true, probs_curr, probs_true_scan)

        input_list_uniform = fitting.generate_input_list(probs_empirical_uniform, amps_scan, 
                                                            T_prev_uniform, w_inits_array_uniform, prob_low,
                                                            disambiguate=disambiguate)

        pool = mp.Pool(processes=24)
        results_uniform = pool.starmap_async(fitting.fit_surface, input_list_uniform)
        mp_output_uniform = results_uniform.get()
        pool.close()

        params_curr_uniform = np.zeros((probs_empirical_uniform.shape[0], probs_empirical_uniform.shape[1]), dtype=object)
        w_inits_array_uniform = np.zeros((probs_empirical_uniform.shape[0], probs_empirical_uniform.shape[1]), dtype=object)
        probs_curr_uniform = np.zeros(probs_empirical_uniform.shape)

        cnt = 0
        for i in range(len(probs_empirical_uniform)):
            for j in range(len(probs_empirical_uniform[i])):
                params_curr_uniform[i][j] = mp_output_uniform[cnt][0]
                w_inits_array_uniform[i][j] = mp_output_uniform[cnt][1]
                
                probs_curr_uniform[i][j] = fitting.sigmoidND_nonlinear(
                                        sm.add_constant(amps_scan[j], has_constant='add'), 
                                        params_curr_uniform[i][j])

                cnt += 1

        performance_uniform = get_performance_array(params_true, probs_curr_uniform, probs_true_scan)
    
    print(performance, performance_uniform)
    
    performances.append(performance)
    performances_uniform.append(performance_uniform)
    
    num_samples.append(np.sum(T_prev))
    num_samples_uniform.append(np.sum(T_prev_uniform))

    iter_cnt += 1

    if iter_cnt > num_iters:
        break

    p_new = sample_spikes_array(probs_true_scan, T_new, NUM_THREADS=24)
    p_tmp = (p_new * T_new[np.newaxis, :, :] + probs_empirical * T_prev[np.newaxis, :, :]) / ((T_new + T_prev)[np.newaxis, :, :])
    T_tmp = T_new + T_prev

    p_tmp = np.nan_to_num(p_tmp, nan=0.5)

    probs_empirical = p_tmp
    T_prev = T_tmp
    
    # random_extra = np.random.choice(len(T_new.flatten()), size=int(np.sum(T_new)), replace=True)
    # T_new_uniform = np.array(np.bincount(random_extra, minlength=len(T_new.flatten())).astype(int).reshape(T_new.shape), dtype=float)
    T_new_uniform = np.ones_like(T_prev_uniform, dtype=float)
    p_new_uniform = sample_spikes_array(probs_true_scan, T_new_uniform, NUM_THREADS=24)

    p_tmp_uniform = (p_new_uniform * T_new_uniform[np.newaxis, :, :] + probs_empirical_uniform * T_prev_uniform[np.newaxis, :, :]) / ((T_prev_uniform + T_new_uniform)[np.newaxis, :, :])
    T_tmp_uniform = T_prev_uniform + T_new_uniform

    p_tmp_uniform = np.nan_to_num(p_tmp_uniform, nan=0.5)

    probs_empirical_uniform = p_tmp_uniform
    T_prev_uniform = T_tmp_uniform
# Out:
# Setting up data...
# Fitting dataset...
# /Volumes/Lab/Users/praful/multielectrode/multielec_src/fitting.py:280: RuntimeWarning: overflow encountered in exp
#   term1 = X.T @ (1 / (1 + np.exp(-X @ w[i].T)))
# Calculating Jacobian...
# Optimizing trials...
# 0
# (DeviceArray(2818627.5, dtype=float32), DeviceArray(378502.62, dtype=float32), DeviceArray(4014441., dtype=float32), DeviceArray(1195813.6, dtype=float32))
# 1
# (DeviceArray(2807014.5, dtype=float32), DeviceArray(363067.56, dtype=float32), DeviceArray(3900462.5, dtype=float32), DeviceArray(1093448., dtype=float32))
# 2
# (DeviceArray(2721447.8, dtype=float32), DeviceArray(367091.22, dtype=float32), DeviceArray(3218124.5, dtype=float32), DeviceArray(496676.75, dtype=float32))
# 3
# (DeviceArray(2624248.5, dtype=float32), DeviceArray(380719.94, dtype=float32), DeviceArray(4148924.5, dtype=float32), DeviceArray(1524675.9, dtype=float32))
# 4
# (DeviceArray(2579054.5, dtype=float32), DeviceArray(382118.56, dtype=float32), DeviceArray(4311168.5, dtype=float32), DeviceArray(1732113.9, dtype=float32))
# 5
# (DeviceArray(2592168., dtype=float32), DeviceArray(375479.62, dtype=float32), DeviceArray(3339623.5, dtype=float32), DeviceArray(747455.4, dtype=float32))
# 6
# (DeviceArray(2633296., dtype=float32), DeviceArray(363172.75, dtype=float32), DeviceArray(3711143., dtype=float32), DeviceArray(1077847.1, dtype=float32))
# 7
# (DeviceArray(2629249.8, dtype=float32), DeviceArray(359542.44, dtype=float32), DeviceArray(4245529., dtype=float32), DeviceArray(1616279.4, dtype=float32))
# 8
# (DeviceArray(2618432., dtype=float32), DeviceArray(362565.88, dtype=float32), DeviceArray(3786288., dtype=float32), DeviceArray(1167856.1, dtype=float32))
# 9
# (DeviceArray(2585048.8, dtype=float32), DeviceArray(370791.62, dtype=float32), DeviceArray(2637200.2, dtype=float32), DeviceArray(52151.5, dtype=float32))
# 10
# (DeviceArray(2570275., dtype=float32), DeviceArray(372570.44, dtype=float32), DeviceArray(2886252.2, dtype=float32), DeviceArray(315977.28, dtype=float32))
# 11
# (DeviceArray(2584720., dtype=float32), DeviceArray(369087.38, dtype=float32), DeviceArray(2785335.5, dtype=float32), DeviceArray(200615.48, dtype=float32))
# 12
# (DeviceArray(2572242.5, dtype=float32), DeviceArray(371013.16, dtype=float32), DeviceArray(2657250.5, dtype=float32), DeviceArray(85008.055, dtype=float32))
# 13
# (DeviceArray(2581121.8, dtype=float32), DeviceArray(368035.12, dtype=float32), DeviceArray(2937802.5, dtype=float32), DeviceArray(356680.66, dtype=float32))
# 14
# (DeviceArray(2535702.5, dtype=float32), DeviceArray(370071.5, dtype=float32), DeviceArray(2590356.8, dtype=float32), DeviceArray(54654.324, dtype=float32))
# 15
# (DeviceArray(2498224., dtype=float32), DeviceArray(376370.72, dtype=float32), DeviceArray(3377842.5, dtype=float32), DeviceArray(879618.56, dtype=float32))
# 16
# (DeviceArray(2494589.5, dtype=float32), DeviceArray(377617.3, dtype=float32), DeviceArray(3559097.5, dtype=float32), DeviceArray(1064508., dtype=float32))
# 17
# (DeviceArray(2504210.5, dtype=float32), DeviceArray(374516.66, dtype=float32), DeviceArray(3108842.5, dtype=float32), DeviceArray(604632., dtype=float32))
# 18
# (DeviceArray(2491042., dtype=float32), DeviceArray(367653.97, dtype=float32), DeviceArray(2904254., dtype=float32), DeviceArray(413212.1, dtype=float32))
# 19
# (DeviceArray(2498467.2, dtype=float32), DeviceArray(365765.5, dtype=float32), DeviceArray(3191769., dtype=float32), DeviceArray(693301.6, dtype=float32))
# 20
# (DeviceArray(2462181.5, dtype=float32), DeviceArray(368204.62, dtype=float32), DeviceArray(2793722.8, dtype=float32), DeviceArray(331541.16, dtype=float32))
# 21
# (DeviceArray(2408894., dtype=float32), DeviceArray(374431.8, dtype=float32), DeviceArray(3000942.5, dtype=float32), DeviceArray(592048.4, dtype=float32))
# 22
# (DeviceArray(2394586.5, dtype=float32), DeviceArray(376052.7, dtype=float32), DeviceArray(3227036., dtype=float32), DeviceArray(832449.5, dtype=float32))
# 23
# (DeviceArray(2387087.2, dtype=float32), DeviceArray(373631.66, dtype=float32), DeviceArray(2860460., dtype=float32), DeviceArray(473372.66, dtype=float32))
# 24
# (DeviceArray(2365315.2, dtype=float32), DeviceArray(367652.03, dtype=float32), DeviceArray(2778814.8, dtype=float32), DeviceArray(413499.47, dtype=float32))
# 25
# (DeviceArray(2361857., dtype=float32), DeviceArray(366222.6, dtype=float32), DeviceArray(2987364.5, dtype=float32), DeviceArray(625507.44, dtype=float32))
# 26
# (DeviceArray(2322725.8, dtype=float32), DeviceArray(368834.53, dtype=float32), DeviceArray(2560842., dtype=float32), DeviceArray(238116.17, dtype=float32))
# 27
# (DeviceArray(2291869., dtype=float32), DeviceArray(375018.06, dtype=float32), DeviceArray(2970867.5, dtype=float32), DeviceArray(678998.44, dtype=float32))
# 28
# (DeviceArray(2263316.8, dtype=float32), DeviceArray(376816.25, dtype=float32), DeviceArray(3209014.5, dtype=float32), DeviceArray(945697.8, dtype=float32))
# 29
# (DeviceArray(2255138., dtype=float32), DeviceArray(374702.38, dtype=float32), DeviceArray(2887315., dtype=float32), DeviceArray(632177., dtype=float32))
# 30
# (DeviceArray(2246424., dtype=float32), DeviceArray(369092.66, dtype=float32), DeviceArray(2446256.2, dtype=float32), DeviceArray(199832.2, dtype=float32))
# 31
# (DeviceArray(2234015., dtype=float32), DeviceArray(367848.34, dtype=float32), DeviceArray(2618398.2, dtype=float32), DeviceArray(384383.25, dtype=float32))
# 32
# (DeviceArray(2225535.5, dtype=float32), DeviceArray(370498.12, dtype=float32), DeviceArray(2234156.2, dtype=float32), DeviceArray(8620.849, dtype=float32))
# 33
# (DeviceArray(2204340., dtype=float32), DeviceArray(369197.78, dtype=float32), DeviceArray(2388580.5, dtype=float32), DeviceArray(184240.52, dtype=float32))
# 34
# (DeviceArray(2189321.5, dtype=float32), DeviceArray(371785.84, dtype=float32), DeviceArray(2388931.2, dtype=float32), DeviceArray(199609.72, dtype=float32))
# 35
# (DeviceArray(2179250.5, dtype=float32), DeviceArray(370448.38, dtype=float32), DeviceArray(2180492.8, dtype=float32), DeviceArray(1242.1438, dtype=float32))
# 36
# (DeviceArray(2178313.2, dtype=float32), DeviceArray(365595.12, dtype=float32), DeviceArray(2896884., dtype=float32), DeviceArray(718570.9, dtype=float32))
# 37
# (DeviceArray(2179591.2, dtype=float32), DeviceArray(364959.66, dtype=float32), DeviceArray(2992412., dtype=float32), DeviceArray(812820.9, dtype=float32))
# 38
# (DeviceArray(2165428.8, dtype=float32), DeviceArray(368117.44, dtype=float32), DeviceArray(2509901.2, dtype=float32), DeviceArray(344472.44, dtype=float32))
# 39
# (DeviceArray(2145997.5, dtype=float32), DeviceArray(374657.78, dtype=float32), DeviceArray(2771560.5, dtype=float32), DeviceArray(625563.06, dtype=float32))
# 40
# (DeviceArray(2138635.5, dtype=float32), DeviceArray(376916.12, dtype=float32), DeviceArray(3099146.2, dtype=float32), DeviceArray(960510.8, dtype=float32))
# 41
# (DeviceArray(2137870.8, dtype=float32), DeviceArray(375334.2, dtype=float32), DeviceArray(2863755.5, dtype=float32), DeviceArray(725884.7, dtype=float32))
# 42
# (DeviceArray(2145077.5, dtype=float32), DeviceArray(370301.7, dtype=float32), DeviceArray(2165591.5, dtype=float32), DeviceArray(20513.912, dtype=float32))
# 43
# (DeviceArray(2143924., dtype=float32), DeviceArray(369460., dtype=float32), DeviceArray(2289273.2, dtype=float32), DeviceArray(145349.36, dtype=float32))
# 44
# (DeviceArray(2130988.8, dtype=float32), DeviceArray(372387.56, dtype=float32), DeviceArray(2419842.8, dtype=float32), DeviceArray(288854.03, dtype=float32))
# 45
# (DeviceArray(2129103., dtype=float32), DeviceArray(371424.47, dtype=float32), DeviceArray(2275115.2, dtype=float32), DeviceArray(146012.14, dtype=float32))
# 46
# (DeviceArray(2131960.5, dtype=float32), DeviceArray(366966.3, dtype=float32), DeviceArray(2647162.8, dtype=float32), DeviceArray(515202.3, dtype=float32))
# 47
# (DeviceArray(2130207.8, dtype=float32), DeviceArray(366655., dtype=float32), DeviceArray(2691582.5, dtype=float32), DeviceArray(561374.8, dtype=float32))
# 48
# (DeviceArray(2118362., dtype=float32), DeviceArray(370057.3, dtype=float32), DeviceArray(2175120.5, dtype=float32), DeviceArray(56758.555, dtype=float32))
# 49
# (DeviceArray(2099896.5, dtype=float32), DeviceArray(376777.44, dtype=float32), DeviceArray(3039837.8, dtype=float32), DeviceArray(939941.3, dtype=float32))
# 50
# (DeviceArray(2076487.6, dtype=float32), DeviceArray(379237.34, dtype=float32), DeviceArray(3381271.5, dtype=float32), DeviceArray(1304784., dtype=float32))
# 51
# (DeviceArray(2072235.9, dtype=float32), DeviceArray(377856.88, dtype=float32), DeviceArray(3172274.8, dtype=float32), DeviceArray(1100038.9, dtype=float32))
# 52
# (DeviceArray(2058576., dtype=float32), DeviceArray(373050.75, dtype=float32), DeviceArray(2445791.2, dtype=float32), DeviceArray(387215.16, dtype=float32))
# 53
# (DeviceArray(2061036.5, dtype=float32), DeviceArray(365141.94, dtype=float32), DeviceArray(2846822.2, dtype=float32), DeviceArray(785785.7, dtype=float32))
# 54
# (DeviceArray(2072335.8, dtype=float32), DeviceArray(361684.6, dtype=float32), DeviceArray(3370899.8, dtype=float32), DeviceArray(1298564., dtype=float32))
# 55
# (DeviceArray(2065751.5, dtype=float32), DeviceArray(362248.94, dtype=float32), DeviceArray(3280614.5, dtype=float32), DeviceArray(1214863., dtype=float32))
# 56
# (DeviceArray(2045578.1, dtype=float32), DeviceArray(366434., dtype=float32), DeviceArray(2639730.8, dtype=float32), DeviceArray(594152.56, dtype=float32))
# 57
# (DeviceArray(2019998.8, dtype=float32), DeviceArray(373872.88, dtype=float32), DeviceArray(2529148., dtype=float32), DeviceArray(509149.16, dtype=float32))
# 58
# (DeviceArray(1994421.2, dtype=float32), DeviceArray(376997.88, dtype=float32), DeviceArray(2967057., dtype=float32), DeviceArray(972635.6, dtype=float32))
# 59
# (DeviceArray(1992073.5, dtype=float32), DeviceArray(376256.97, dtype=float32), DeviceArray(2854821., dtype=float32), DeviceArray(862747.6, dtype=float32))
# 60
# (DeviceArray(2002096.6, dtype=float32), DeviceArray(372012.88, dtype=float32), DeviceArray(2235378.8, dtype=float32), DeviceArray(233282.02, dtype=float32))
# 61
# (DeviceArray(2022367.8, dtype=float32), DeviceArray(364642.25, dtype=float32), DeviceArray(2882265., dtype=float32), DeviceArray(859897.2, dtype=float32))
# 62
# (DeviceArray(2014660.5, dtype=float32), DeviceArray(361673.25, dtype=float32), DeviceArray(3314907., dtype=float32), DeviceArray(1300246.4, dtype=float32))
# 63
# (DeviceArray(2008794., dtype=float32), DeviceArray(362663.1, dtype=float32), DeviceArray(3162231., dtype=float32), DeviceArray(1153437.1, dtype=float32))
# 64
# (DeviceArray(2001023., dtype=float32), DeviceArray(367213.78, dtype=float32), DeviceArray(2479521.8, dtype=float32), DeviceArray(478498.8, dtype=float32))
# 65
# (DeviceArray(1988360.2, dtype=float32), DeviceArray(374950.53, dtype=float32), DeviceArray(2657342.8, dtype=float32), DeviceArray(668982.5, dtype=float32))
# 66
# (DeviceArray(1972637.4, dtype=float32), DeviceArray(378344.72, dtype=float32), DeviceArray(3145031., dtype=float32), DeviceArray(1172393.8, dtype=float32))
# 67
# (DeviceArray(1967461., dtype=float32), DeviceArray(377828.16, dtype=float32), DeviceArray(3063240.5, dtype=float32), DeviceArray(1095779.4, dtype=float32))
# 68
# (DeviceArray(1971107.6, dtype=float32), DeviceArray(373795.88, dtype=float32), DeviceArray(2468836.5, dtype=float32), DeviceArray(497728.88, dtype=float32))
# 69
# (DeviceArray(1992589.6, dtype=float32), DeviceArray(366624.22, dtype=float32), DeviceArray(2558529.8, dtype=float32), DeviceArray(565940.2, dtype=float32))
# 70
# (DeviceArray(1993057.8, dtype=float32), DeviceArray(363833.03, dtype=float32), DeviceArray(2972974.8, dtype=float32), DeviceArray(979917., dtype=float32))
# 71
# (DeviceArray(1990186.5, dtype=float32), DeviceArray(364975.84, dtype=float32), DeviceArray(2800606.5, dtype=float32), DeviceArray(810420., dtype=float32))
# 72
# (DeviceArray(1969122.1, dtype=float32), DeviceArray(369662.25, dtype=float32), DeviceArray(2084474.6, dtype=float32), DeviceArray(115352.516, dtype=float32))
# 73
# (DeviceArray(1948703.2, dtype=float32), DeviceArray(377529.5, dtype=float32), DeviceArray(3000187.2, dtype=float32), DeviceArray(1051484., dtype=float32))
# 74
# (DeviceArray(1927855., dtype=float32), DeviceArray(381048.12, dtype=float32), DeviceArray(3501206.2, dtype=float32), DeviceArray(1573351.2, dtype=float32))
# 75
# (DeviceArray(1927912.8, dtype=float32), DeviceArray(380645.06, dtype=float32), DeviceArray(3441483.5, dtype=float32), DeviceArray(1513570.8, dtype=float32))
# 76
# (DeviceArray(1932481.4, dtype=float32), DeviceArray(376723.88, dtype=float32), DeviceArray(2864478.5, dtype=float32), DeviceArray(931997.1, dtype=float32))
# 77
# (DeviceArray(1944027.5, dtype=float32), DeviceArray(369655.3, dtype=float32), DeviceArray(2060409., dtype=float32), DeviceArray(116381.45, dtype=float32))
# 78
# (DeviceArray(1941184.5, dtype=float32), DeviceArray(366943.38, dtype=float32), DeviceArray(2459788.8, dtype=float32), DeviceArray(518604.28, dtype=float32))
# 79
# (DeviceArray(1935573.6, dtype=float32), DeviceArray(368152.62, dtype=float32), DeviceArray(2274827.2, dtype=float32), DeviceArray(339253.56, dtype=float32))
# 80
# (DeviceArray(1925808.5, dtype=float32), DeviceArray(372875.1, dtype=float32), DeviceArray(2286971., dtype=float32), DeviceArray(361162.56, dtype=float32))
# 81
# (DeviceArray(1923734.2, dtype=float32), DeviceArray(373560.3, dtype=float32), DeviceArray(2386525.5, dtype=float32), DeviceArray(462791.25, dtype=float32))
# 82
# (DeviceArray(1923545.9, dtype=float32), DeviceArray(370609.88, dtype=float32), DeviceArray(1948741., dtype=float32), DeviceArray(25195.125, dtype=float32))
# 83
# (DeviceArray(1938720.8, dtype=float32), DeviceArray(364390.56, dtype=float32), DeviceArray(2835947., dtype=float32), DeviceArray(897226.4, dtype=float32))
# 84
# (DeviceArray(1934043.5, dtype=float32), DeviceArray(362445.88, dtype=float32), DeviceArray(3119697.5, dtype=float32), DeviceArray(1185654., dtype=float32))
# 85
# (DeviceArray(1926522.6, dtype=float32), DeviceArray(364329.44, dtype=float32), DeviceArray(2832814.8, dtype=float32), DeviceArray(906292.2, dtype=float32))
# 86
# (DeviceArray(1917478.6, dtype=float32), DeviceArray(369659.53, dtype=float32), DeviceArray(2033234.4, dtype=float32), DeviceArray(115755.75, dtype=float32))
# 87
# (DeviceArray(1900824.6, dtype=float32), DeviceArray(378088.88, dtype=float32), DeviceArray(3035272.5, dtype=float32), DeviceArray(1134448., dtype=float32))
# 88
# (DeviceArray(1894331.5, dtype=float32), DeviceArray(382116.06, dtype=float32), DeviceArray(3626074.5, dtype=float32), DeviceArray(1731743.1, dtype=float32))
# 89
# (DeviceArray(1889077.1, dtype=float32), DeviceArray(382174.44, dtype=float32), DeviceArray(3629478., dtype=float32), DeviceArray(1740401., dtype=float32))
# 90
# (DeviceArray(1885633., dtype=float32), DeviceArray(378659.22, dtype=float32), DeviceArray(3104672., dtype=float32), DeviceArray(1219039., dtype=float32))
# 91
# (DeviceArray(1899809., dtype=float32), DeviceArray(371945.94, dtype=float32), DeviceArray(2123163.2, dtype=float32), DeviceArray(223354.14, dtype=float32))
# 92
# (DeviceArray(1926382.8, dtype=float32), DeviceArray(362361.3, dtype=float32), DeviceArray(3124578.8, dtype=float32), DeviceArray(1198196., dtype=float32))
# 93
# (DeviceArray(1941486.9, dtype=float32), DeviceArray(357389.8, dtype=float32), DeviceArray(3877034.2, dtype=float32), DeviceArray(1935547.4, dtype=float32))
# 94
# (DeviceArray(1930248., dtype=float32), DeviceArray(356565.5, dtype=float32), DeviceArray(3988054., dtype=float32), DeviceArray(2057805.9, dtype=float32))
# 95
# (DeviceArray(1921265.6, dtype=float32), DeviceArray(359472.78, dtype=float32), DeviceArray(3547876., dtype=float32), DeviceArray(1626610.5, dtype=float32))
# 96
# (DeviceArray(1883857.1, dtype=float32), DeviceArray(365728.38, dtype=float32), DeviceArray(2582665., dtype=float32), DeviceArray(698807.8, dtype=float32))
# 97
# (DeviceArray(1866005.5, dtype=float32), DeviceArray(374988.28, dtype=float32), DeviceArray(2540587., dtype=float32), DeviceArray(674581.4, dtype=float32))
# 98
# (DeviceArray(1854293.8, dtype=float32), DeviceArray(379761.7, dtype=float32), DeviceArray(3236846., dtype=float32), DeviceArray(1382552.4, dtype=float32))
# 99
# (DeviceArray(1845164., dtype=float32), DeviceArray(380495.56, dtype=float32), DeviceArray(3336561.5, dtype=float32), DeviceArray(1491397.5, dtype=float32))
# 100
# (DeviceArray(1844871.2, dtype=float32), DeviceArray(377611.2, dtype=float32), DeviceArray(2908470.8, dtype=float32), DeviceArray(1063599.5, dtype=float32))
# 101
# (DeviceArray(1848562.1, dtype=float32), DeviceArray(371445.12, dtype=float32), DeviceArray(1997637.9, dtype=float32), DeviceArray(149075.8, dtype=float32))
# 102
# (DeviceArray(1859610.1, dtype=float32), DeviceArray(362327.75, dtype=float32), DeviceArray(3062784., dtype=float32), DeviceArray(1203173.9, dtype=float32))
# 103
# (DeviceArray(1869507.5, dtype=float32), DeviceArray(357752.44, dtype=float32), DeviceArray(3751272., dtype=float32), DeviceArray(1881764.4, dtype=float32))
# 104
# (DeviceArray(1861832., dtype=float32), DeviceArray(357280.12, dtype=float32), DeviceArray(3813647.8, dtype=float32), DeviceArray(1951815.8, dtype=float32))
# 105
# (DeviceArray(1854275.5, dtype=float32), DeviceArray(360488.06, dtype=float32), DeviceArray(3330304., dtype=float32), DeviceArray(1476028.4, dtype=float32))
# 106
# (DeviceArray(1836672.2, dtype=float32), DeviceArray(367009.16, dtype=float32), DeviceArray(2345520.2, dtype=float32), DeviceArray(508847.9, dtype=float32))
# 107
# (DeviceArray(1821257.5, dtype=float32), DeviceArray(376511.8, dtype=float32), DeviceArray(2721802.5, dtype=float32), DeviceArray(900544.94, dtype=float32))
# 108
# (DeviceArray(1814120.5, dtype=float32), DeviceArray(381504.12, dtype=float32), DeviceArray(3455103.5, dtype=float32), DeviceArray(1640983.1, dtype=float32))
# 109
# (DeviceArray(1808220., dtype=float32), DeviceArray(382428.94, dtype=float32), DeviceArray(3586367.5, dtype=float32), DeviceArray(1778147.4, dtype=float32))
# 110
# (DeviceArray(1809467.5, dtype=float32), DeviceArray(379690.25, dtype=float32), DeviceArray(3181424.5, dtype=float32), DeviceArray(1371957., dtype=float32))
# 111
# (DeviceArray(1816113., dtype=float32), DeviceArray(373659.72, dtype=float32), DeviceArray(2293647.8, dtype=float32), DeviceArray(477534.75, dtype=float32))
# 112
# (DeviceArray(1827637., dtype=float32), DeviceArray(364679.44, dtype=float32), DeviceArray(2682018.8, dtype=float32), DeviceArray(854381.7, dtype=float32))
# 113
# (DeviceArray(1825932.5, dtype=float32), DeviceArray(360249.4, dtype=float32), DeviceArray(3337357.2, dtype=float32), DeviceArray(1511424.8, dtype=float32))
# 114
# (DeviceArray(1826466.5, dtype=float32), DeviceArray(359913.8, dtype=float32), DeviceArray(3387665., dtype=float32), DeviceArray(1561198.6, dtype=float32))
# 115
# (DeviceArray(1808335.2, dtype=float32), DeviceArray(363245.25, dtype=float32), DeviceArray(2875429.5, dtype=float32), DeviceArray(1067094.2, dtype=float32))
# 116
# (DeviceArray(1783105.2, dtype=float32), DeviceArray(369874.8, dtype=float32), DeviceArray(1866931.4, dtype=float32), DeviceArray(83826.164, dtype=float32))
# 117
# (DeviceArray(1762927., dtype=float32), DeviceArray(379474.38, dtype=float32), DeviceArray(3102866.5, dtype=float32), DeviceArray(1339939.4, dtype=float32))
# 118
# (DeviceArray(1753737.1, dtype=float32), DeviceArray(384544.8, dtype=float32), DeviceArray(3845702., dtype=float32), DeviceArray(2091964.8, dtype=float32))
# 119
# (DeviceArray(1751960.4, dtype=float32), DeviceArray(385534.25, dtype=float32), DeviceArray(3990674., dtype=float32), DeviceArray(2238713.8, dtype=float32))
# 120
# (DeviceArray(1751348.5, dtype=float32), DeviceArray(382847.62, dtype=float32), DeviceArray(3591593.8, dtype=float32), DeviceArray(1840245.2, dtype=float32))
# 121
# (DeviceArray(1758832.2, dtype=float32), DeviceArray(376873.47, dtype=float32), DeviceArray(2713016.5, dtype=float32), DeviceArray(954184.25, dtype=float32))
# 122
# (DeviceArray(1770016.2, dtype=float32), DeviceArray(367926.28, dtype=float32), DeviceArray(2142840., dtype=float32), DeviceArray(372823.88, dtype=float32))
# 123
# (DeviceArray(1773684.5, dtype=float32), DeviceArray(363507.8, dtype=float32), DeviceArray(2801836.5, dtype=float32), DeviceArray(1028152.06, dtype=float32))
# 124
# (DeviceArray(1770598.5, dtype=float32), DeviceArray(363167.3, dtype=float32), DeviceArray(2849252., dtype=float32), DeviceArray(1078653.5, dtype=float32))
# 125
# (DeviceArray(1764307.1, dtype=float32), DeviceArray(366494.6, dtype=float32), DeviceArray(2349472.8, dtype=float32), DeviceArray(585165.56, dtype=float32))
# 126
# (DeviceArray(1755612.6, dtype=float32), DeviceArray(373121.5, dtype=float32), DeviceArray(2153321., dtype=float32), DeviceArray(397708.47, dtype=float32))
# 127
# (DeviceArray(1751198.4, dtype=float32), DeviceArray(375508.66, dtype=float32), DeviceArray(2502959.5, dtype=float32), DeviceArray(751761.2, dtype=float32))
# 128
# (DeviceArray(1751481.2, dtype=float32), DeviceArray(374081.5, dtype=float32), DeviceArray(2291572.8, dtype=float32), DeviceArray(540091.5, dtype=float32))
# 129
# (DeviceArray(1755246.1, dtype=float32), DeviceArray(369220.75, dtype=float32), DeviceArray(1936080., dtype=float32), DeviceArray(180833.89, dtype=float32))
# 130
# (DeviceArray(1747295.2, dtype=float32), DeviceArray(368495.03, dtype=float32), DeviceArray(2035764.6, dtype=float32), DeviceArray(288469.34, dtype=float32))
# 131
# (DeviceArray(1742551.2, dtype=float32), DeviceArray(371491.4, dtype=float32), DeviceArray(1898491.2, dtype=float32), DeviceArray(155940.03, dtype=float32))
# 132
# (DeviceArray(1741541.5, dtype=float32), DeviceArray(370613.62, dtype=float32), DeviceArray(1767292.8, dtype=float32), DeviceArray(25751.309, dtype=float32))
# 133
# (DeviceArray(1746845.8, dtype=float32), DeviceArray(366248.56, dtype=float32), DeviceArray(2368501.5, dtype=float32), DeviceArray(621655.9, dtype=float32))
# 134
# (DeviceArray(1741190.6, dtype=float32), DeviceArray(365967.3, dtype=float32), DeviceArray(2404560.2, dtype=float32), DeviceArray(663369.7, dtype=float32))
# 135
# (DeviceArray(1734275.8, dtype=float32), DeviceArray(369358.47, dtype=float32), DeviceArray(1894683.8, dtype=float32), DeviceArray(160408.03, dtype=float32))
# 136
# (DeviceArray(1725731.5, dtype=float32), DeviceArray(376052.4, dtype=float32), DeviceArray(2558139.2, dtype=float32), DeviceArray(832407.8, dtype=float32))
# 137
# (DeviceArray(1720783.5, dtype=float32), DeviceArray(378499.56, dtype=float32), DeviceArray(2916143., dtype=float32), DeviceArray(1195359.5, dtype=float32))
# 138
# (DeviceArray(1721875., dtype=float32), DeviceArray(377122.84, dtype=float32), DeviceArray(2713045.5, dtype=float32), DeviceArray(991170.5, dtype=float32))
# 139
# (DeviceArray(1717492.8, dtype=float32), DeviceArray(372306.2, dtype=float32), DeviceArray(1994277.6, dtype=float32), DeviceArray(276784.84, dtype=float32))
# 140
# (DeviceArray(1725496.8, dtype=float32), DeviceArray(364392.4, dtype=float32), DeviceArray(2622449.8, dtype=float32), DeviceArray(896952.94, dtype=float32))
# 141
# (DeviceArray(1724805., dtype=float32), DeviceArray(360907.6, dtype=float32), DeviceArray(3138610.2, dtype=float32), DeviceArray(1413805.2, dtype=float32))
# 142
# (DeviceArray(1721147.4, dtype=float32), DeviceArray(361421.7, dtype=float32), DeviceArray(3058704.5, dtype=float32), DeviceArray(1337557.1, dtype=float32))
# 143
# (DeviceArray(1713070.2, dtype=float32), DeviceArray(365536.8, dtype=float32), DeviceArray(2440289.8, dtype=float32), DeviceArray(727219.56, dtype=float32))
# 144
# (DeviceArray(1700363.2, dtype=float32), DeviceArray(372895.2, dtype=float32), DeviceArray(2064506., dtype=float32), DeviceArray(364142.78, dtype=float32))
# 145
# (DeviceArray(1690726.6, dtype=float32), DeviceArray(375938.8, dtype=float32), DeviceArray(2506286.8, dtype=float32), DeviceArray(815560.06, dtype=float32))
# 146
# (DeviceArray(1685692.5, dtype=float32), DeviceArray(375096.5, dtype=float32), DeviceArray(2376324.5, dtype=float32), DeviceArray(690631.94, dtype=float32))
# 147
# (DeviceArray(1686485.2, dtype=float32), DeviceArray(370757.12, dtype=float32), DeviceArray(1733519.9, dtype=float32), DeviceArray(47034.61, dtype=float32))
# 148
# (DeviceArray(1702619., dtype=float32), DeviceArray(363282.8, dtype=float32), DeviceArray(2764142., dtype=float32), DeviceArray(1061523.1, dtype=float32))
# 149
# (DeviceArray(1702498.8, dtype=float32), DeviceArray(360205.12, dtype=float32), DeviceArray(3220491., dtype=float32), DeviceArray(1517992.4, dtype=float32))
# 150
# (DeviceArray(1697461.8, dtype=float32), DeviceArray(361084.72, dtype=float32), DeviceArray(3084996.5, dtype=float32), DeviceArray(1387534.9, dtype=float32))
# 151
# (DeviceArray(1685448.5, dtype=float32), DeviceArray(365530.62, dtype=float32), DeviceArray(2413585.8, dtype=float32), DeviceArray(728137.25, dtype=float32))
# 152
# (DeviceArray(1675342.5, dtype=float32), DeviceArray(373181.4, dtype=float32), DeviceArray(2081936., dtype=float32), DeviceArray(406593.5, dtype=float32))
# 153
# (DeviceArray(1665804.2, dtype=float32), DeviceArray(376490.6, dtype=float32), DeviceArray(2563202., dtype=float32), DeviceArray(897397.9, dtype=float32))
# 154
# (DeviceArray(1665336., dtype=float32), DeviceArray(375888.75, dtype=float32), DeviceArray(2473471., dtype=float32), DeviceArray(808135., dtype=float32))
# 155
# (DeviceArray(1671228.1, dtype=float32), DeviceArray(371762.12, dtype=float32), DeviceArray(1867320., dtype=float32), DeviceArray(196091.86, dtype=float32))
# 156
# (DeviceArray(1675603., dtype=float32), DeviceArray(364480.4, dtype=float32), DeviceArray(2559504.2, dtype=float32), DeviceArray(883901.2, dtype=float32))
# 157
# (DeviceArray(1677920.2, dtype=float32), DeviceArray(361566.97, dtype=float32), DeviceArray(2993930., dtype=float32), DeviceArray(1316009.6, dtype=float32))
# 158
# (DeviceArray(1675058.8, dtype=float32), DeviceArray(362584.2, dtype=float32), DeviceArray(2840199., dtype=float32), DeviceArray(1165140.1, dtype=float32))
# 159
# (DeviceArray(1663269.4, dtype=float32), DeviceArray(367140.12, dtype=float32), DeviceArray(2152692.5, dtype=float32), DeviceArray(489423.2, dtype=float32))
# 160
# (DeviceArray(1650204.2, dtype=float32), DeviceArray(374892.9, dtype=float32), DeviceArray(2310640., dtype=float32), DeviceArray(660435.8, dtype=float32))
# 161
# (DeviceArray(1643662.6, dtype=float32), DeviceArray(378290.47, dtype=float32), DeviceArray(2808010.2, dtype=float32), DeviceArray(1164347.6, dtype=float32))
# 162
# (DeviceArray(1643252.4, dtype=float32), DeviceArray(377778.5, dtype=float32), DeviceArray(2731667., dtype=float32), DeviceArray(1088414.6, dtype=float32))
# 163
# (DeviceArray(1649866.2, dtype=float32), DeviceArray(373731.62, dtype=float32), DeviceArray(2138065.8, dtype=float32), DeviceArray(488199.6, dtype=float32))
# 164
# (DeviceArray(1656807.8, dtype=float32), DeviceArray(366514.88, dtype=float32), DeviceArray(2238965.2, dtype=float32), DeviceArray(582157.56, dtype=float32))
# 165
# (DeviceArray(1660951.8, dtype=float32), DeviceArray(363664.3, dtype=float32), DeviceArray(2665892.5, dtype=float32), DeviceArray(1004940.7, dtype=float32))
# 166
# (DeviceArray(1658119.5, dtype=float32), DeviceArray(364753.25, dtype=float32), DeviceArray(2501553.8, dtype=float32), DeviceArray(843434.2, dtype=float32))
# 167
# (DeviceArray(1650769., dtype=float32), DeviceArray(369373.56, dtype=float32), DeviceArray(1808938.4, dtype=float32), DeviceArray(158169.39, dtype=float32))
# 168
# (DeviceArray(1637850., dtype=float32), DeviceArray(377182.9, dtype=float32), DeviceArray(2637928.8, dtype=float32), DeviceArray(1000078.7, dtype=float32))
# 169
# (DeviceArray(1633361.8, dtype=float32), DeviceArray(380625.28, dtype=float32), DeviceArray(3143998.5, dtype=float32), DeviceArray(1510636.9, dtype=float32))
# 170
# (DeviceArray(1629273.5, dtype=float32), DeviceArray(380139.38, dtype=float32), DeviceArray(3067843., dtype=float32), DeviceArray(1438569.4, dtype=float32))
# 171
# (DeviceArray(1631475.4, dtype=float32), DeviceArray(376115.06, dtype=float32), DeviceArray(2473176., dtype=float32), DeviceArray(841700.7, dtype=float32))
# 172
# (DeviceArray(1641511.5, dtype=float32), DeviceArray(368902.94, dtype=float32), DeviceArray(1869482., dtype=float32), DeviceArray(227970.45, dtype=float32))
# 173
# (DeviceArray(1642837.2, dtype=float32), DeviceArray(366070.4, dtype=float32), DeviceArray(2290916.5, dtype=float32), DeviceArray(648079.25, dtype=float32))
# 174
# (DeviceArray(1639585.8, dtype=float32), DeviceArray(367162.3, dtype=float32), DeviceArray(2125718.2, dtype=float32), DeviceArray(486132.44, dtype=float32))
# 175
# (DeviceArray(1633358.5, dtype=float32), DeviceArray(371797.5, dtype=float32), DeviceArray(1834697., dtype=float32), DeviceArray(201338.53, dtype=float32))
# 176
# (DeviceArray(1632100., dtype=float32), DeviceArray(372381.75, dtype=float32), DeviceArray(1920092., dtype=float32), DeviceArray(287991.97, dtype=float32))
# 177
# (DeviceArray(1633927.4, dtype=float32), DeviceArray(369318.06, dtype=float32), DeviceArray(1800328.2, dtype=float32), DeviceArray(166400.92, dtype=float32))
# 178
# (DeviceArray(1632502., dtype=float32), DeviceArray(370215.16, dtype=float32), DeviceArray(1665849.9, dtype=float32), DeviceArray(33347.85, dtype=float32))
# 179
# (DeviceArray(1607490.9, dtype=float32), DeviceArray(374678.25, dtype=float32), DeviceArray(2236089.8, dtype=float32), DeviceArray(628598.9, dtype=float32))
# 180
# (DeviceArray(1606118.2, dtype=float32), DeviceArray(375117.28, dtype=float32), DeviceArray(2299832.5, dtype=float32), DeviceArray(693714.1, dtype=float32))
# 181
# (DeviceArray(1605902.4, dtype=float32), DeviceArray(371936.72, dtype=float32), DeviceArray(1827889.2, dtype=float32), DeviceArray(221986.84, dtype=float32))
# 182
# (DeviceArray(1610201.2, dtype=float32), DeviceArray(365499.62, dtype=float32), DeviceArray(2342936.2, dtype=float32), DeviceArray(732735.06, dtype=float32))
# 183
# (DeviceArray(1611993., dtype=float32), DeviceArray(363347.3, dtype=float32), DeviceArray(2663949.8, dtype=float32), DeviceArray(1051956.8, dtype=float32))
# 184
# (DeviceArray(1607174.2, dtype=float32), DeviceArray(365053.34, dtype=float32), DeviceArray(2406099.8, dtype=float32), DeviceArray(798925.56, dtype=float32))
# 185
# (DeviceArray(1601680.1, dtype=float32), DeviceArray(370242.7, dtype=float32), DeviceArray(1630944.6, dtype=float32), DeviceArray(29264.537, dtype=float32))
# 186
# (DeviceArray(1592558.2, dtype=float32), DeviceArray(378554.56, dtype=float32), DeviceArray(2796075., dtype=float32), DeviceArray(1203516.8, dtype=float32))
# 187
# (DeviceArray(1587417., dtype=float32), DeviceArray(382445.62, dtype=float32), DeviceArray(3368039.5, dtype=float32), DeviceArray(1780622.4, dtype=float32))
# 188
# (DeviceArray(1585745.8, dtype=float32), DeviceArray(382359.12, dtype=float32), DeviceArray(3353538.8, dtype=float32), DeviceArray(1767793., dtype=float32))
# 189
# (DeviceArray(1589053.8, dtype=float32), DeviceArray(378688.44, dtype=float32), DeviceArray(2812426.5, dtype=float32), DeviceArray(1223372.6, dtype=float32))
# 190
# (DeviceArray(1595228.5, dtype=float32), DeviceArray(371793.62, dtype=float32), DeviceArray(1795992.2, dtype=float32), DeviceArray(200763.8, dtype=float32))
# 191
# (DeviceArray(1601860.2, dtype=float32), DeviceArray(361995.88, dtype=float32), DeviceArray(2854256.5, dtype=float32), DeviceArray(1252396.1, dtype=float32))
# 192
# (DeviceArray(1601656.5, dtype=float32), DeviceArray(360303.66, dtype=float32), DeviceArray(3105035., dtype=float32), DeviceArray(1503378.6, dtype=float32))
# 193
# (DeviceArray(1597429.1, dtype=float32), DeviceArray(363159.7, dtype=float32), DeviceArray(2677213.5, dtype=float32), DeviceArray(1079784.5, dtype=float32))
# 194
# (DeviceArray(1592040., dtype=float32), DeviceArray(369379.75, dtype=float32), DeviceArray(1749291.8, dtype=float32), DeviceArray(157251.69, dtype=float32))
# 195
# (DeviceArray(1582766.5, dtype=float32), DeviceArray(378622., dtype=float32), DeviceArray(2796285.5, dtype=float32), DeviceArray(1213518.9, dtype=float32))
# 196
# (DeviceArray(1579698.2, dtype=float32), DeviceArray(383360.1, dtype=float32), DeviceArray(3495950.5, dtype=float32), DeviceArray(1916252.4, dtype=float32))
# 197
# (DeviceArray(1577406.2, dtype=float32), DeviceArray(384044.3, dtype=float32), DeviceArray(3595139., dtype=float32), DeviceArray(2017732.8, dtype=float32))
# 198
# (DeviceArray(1583767.9, dtype=float32), DeviceArray(381070.78, dtype=float32), DeviceArray(3160479.5, dtype=float32), DeviceArray(1576711.5, dtype=float32))
# 199
# (DeviceArray(1597392.9, dtype=float32), DeviceArray(374928.88, dtype=float32), DeviceArray(2263163.5, dtype=float32), DeviceArray(665770.5, dtype=float32))
# 200
# (DeviceArray(1609376., dtype=float32), DeviceArray(366257.8, dtype=float32), DeviceArray(2229660., dtype=float32), DeviceArray(620283.94, dtype=float32))
# 201
# (DeviceArray(1612519.8, dtype=float32), DeviceArray(362388.75, dtype=float32), DeviceArray(2806646.5, dtype=float32), DeviceArray(1194126.6, dtype=float32))
# 202
# (DeviceArray(1613983.2, dtype=float32), DeviceArray(362603., dtype=float32), DeviceArray(2776333., dtype=float32), DeviceArray(1162349.9, dtype=float32))
# 203
# (DeviceArray(1608935.2, dtype=float32), DeviceArray(366459.53, dtype=float32), DeviceArray(2199301., dtype=float32), DeviceArray(590365.9, dtype=float32))
# 204
# (DeviceArray(1596254.8, dtype=float32), DeviceArray(373590.12, dtype=float32), DeviceArray(2063467.6, dtype=float32), DeviceArray(467212.9, dtype=float32))
# 205
# (DeviceArray(1590797.1, dtype=float32), DeviceArray(376416.78, dtype=float32), DeviceArray(2477247.5, dtype=float32), DeviceArray(886450.3, dtype=float32))
# 206
# (DeviceArray(1589699., dtype=float32), DeviceArray(375367.4, dtype=float32), DeviceArray(2320510.5, dtype=float32), DeviceArray(730811.56, dtype=float32))
# 207
# (DeviceArray(1598864.8, dtype=float32), DeviceArray(370843.3, dtype=float32), DeviceArray(1658682.4, dtype=float32), DeviceArray(59817.566, dtype=float32))
# 208
# (DeviceArray(1605157.5, dtype=float32), DeviceArray(363267.88, dtype=float32), DeviceArray(2668896., dtype=float32), DeviceArray(1063738.5, dtype=float32))
# 209
# (DeviceArray(1608873.8, dtype=float32), DeviceArray(360173.16, dtype=float32), DeviceArray(3131607.5, dtype=float32), DeviceArray(1522733.9, dtype=float32))
# 210
# (DeviceArray(1607331.4, dtype=float32), DeviceArray(361047.75, dtype=float32), DeviceArray(3000349.2, dtype=float32), DeviceArray(1393017.9, dtype=float32))
# 211
# (DeviceArray(1601622.2, dtype=float32), DeviceArray(365481.25, dtype=float32), DeviceArray(2337082.5, dtype=float32), DeviceArray(735460.4, dtype=float32))
# 212
# (DeviceArray(1591306.8, dtype=float32), DeviceArray(373119.38, dtype=float32), DeviceArray(1988700., dtype=float32), DeviceArray(397393.3, dtype=float32))
# 213
# (DeviceArray(1587880.8, dtype=float32), DeviceArray(376400.28, dtype=float32), DeviceArray(2471884., dtype=float32), DeviceArray(884003.1, dtype=float32))
# 214
# (DeviceArray(1589502., dtype=float32), DeviceArray(375758.88, dtype=float32), DeviceArray(2378374.5, dtype=float32), DeviceArray(788872.5, dtype=float32))
# 215
# (DeviceArray(1589506.2, dtype=float32), DeviceArray(371596.3, dtype=float32), DeviceArray(1761005.5, dtype=float32), DeviceArray(171499.27, dtype=float32))
# 216
# (DeviceArray(1601316.8, dtype=float32), DeviceArray(364261.2, dtype=float32), DeviceArray(2517731.5, dtype=float32), DeviceArray(916414.75, dtype=float32))
# 217
# (DeviceArray(1601472.5, dtype=float32), DeviceArray(361347.75, dtype=float32), DeviceArray(2949995.5, dtype=float32), DeviceArray(1348523.1, dtype=float32))
# 218
# (DeviceArray(1599956.5, dtype=float32), DeviceArray(362384.2, dtype=float32), DeviceArray(2794759.8, dtype=float32), DeviceArray(1194803.2, dtype=float32))
# 219
# (DeviceArray(1591122., dtype=float32), DeviceArray(366977.44, dtype=float32), DeviceArray(2104674.2, dtype=float32), DeviceArray(513552.28, dtype=float32))
# 220
# (DeviceArray(1579940., dtype=float32), DeviceArray(374772.47, dtype=float32), DeviceArray(2222513., dtype=float32), DeviceArray(642573., dtype=float32))
# 221
# (DeviceArray(1574785.5, dtype=float32), DeviceArray(378203.62, dtype=float32), DeviceArray(2726252.8, dtype=float32), DeviceArray(1151467.2, dtype=float32))
# 222
# (DeviceArray(1576084.8, dtype=float32), DeviceArray(377694.5, dtype=float32), DeviceArray(2652040.8, dtype=float32), DeviceArray(1075956., dtype=float32))
# 223
# (DeviceArray(1580424.2, dtype=float32), DeviceArray(373650.94, dtype=float32), DeviceArray(2056656.6, dtype=float32), DeviceArray(476232.34, dtype=float32))
# 224
# (DeviceArray(1590547.4, dtype=float32), DeviceArray(366418.62, dtype=float32), DeviceArray(2186980.2, dtype=float32), DeviceArray(596432.94, dtype=float32))
# 225
# (DeviceArray(1592067.5, dtype=float32), DeviceArray(363573.34, dtype=float32), DeviceArray(2610500.2, dtype=float32), DeviceArray(1018432.75, dtype=float32))
# 226
# (DeviceArray(1588630., dtype=float32), DeviceArray(364678.38, dtype=float32), DeviceArray(2443169.2, dtype=float32), DeviceArray(854539.3, dtype=float32))
# 227
# (DeviceArray(1583310.8, dtype=float32), DeviceArray(369320.03, dtype=float32), DeviceArray(1749419.6, dtype=float32), DeviceArray(166108.92, dtype=float32))
# 228
# (DeviceArray(1573303.2, dtype=float32), DeviceArray(377146., dtype=float32), DeviceArray(2567908.2, dtype=float32), DeviceArray(994604.94, dtype=float32))
# 229
# (DeviceArray(1561975.1, dtype=float32), DeviceArray(380591.2, dtype=float32), DeviceArray(3067555.5, dtype=float32), DeviceArray(1505580.2, dtype=float32))
# 230
# (DeviceArray(1559840.5, dtype=float32), DeviceArray(380104.5, dtype=float32), DeviceArray(2993237.5, dtype=float32), DeviceArray(1433396.9, dtype=float32))
# 231
# (DeviceArray(1562445.2, dtype=float32), DeviceArray(376068.88, dtype=float32), DeviceArray(2397295.5, dtype=float32), DeviceArray(834850.4, dtype=float32))
# 232
# (DeviceArray(1570079.5, dtype=float32), DeviceArray(368838.38, dtype=float32), DeviceArray(1807625.6, dtype=float32), DeviceArray(237546.1, dtype=float32))
# 233
# (DeviceArray(1573046., dtype=float32), DeviceArray(365990.44, dtype=float32), DeviceArray(2232986., dtype=float32), DeviceArray(659939.9, dtype=float32))
# 234
# (DeviceArray(1568371.8, dtype=float32), DeviceArray(367078.88, dtype=float32), DeviceArray(2066879.2, dtype=float32), DeviceArray(498507.53, dtype=float32))
# 235
# (DeviceArray(1560966.8, dtype=float32), DeviceArray(371707.62, dtype=float32), DeviceArray(1748975.4, dtype=float32), DeviceArray(188008.66, dtype=float32))
# 236
# (DeviceArray(1558775.9, dtype=float32), DeviceArray(372275.16, dtype=float32), DeviceArray(1830958.2, dtype=float32), DeviceArray(272182.44, dtype=float32))
# 237
# (DeviceArray(1554395.5, dtype=float32), DeviceArray(369188., dtype=float32), DeviceArray(1740086.8, dtype=float32), DeviceArray(185691.22, dtype=float32))
# 238
# (DeviceArray(1553461.2, dtype=float32), DeviceArray(370059.1, dtype=float32), DeviceArray(1609955.6, dtype=float32), DeviceArray(56494.367, dtype=float32))
# 239
# (DeviceArray(1547175.2, dtype=float32), DeviceArray(374494.25, dtype=float32), DeviceArray(2148484., dtype=float32), DeviceArray(601308.8, dtype=float32))
# 240
# (DeviceArray(1545333., dtype=float32), DeviceArray(374887.56, dtype=float32), DeviceArray(2204976.2, dtype=float32), DeviceArray(659643.25, dtype=float32))
# 241
# (DeviceArray(1550411.5, dtype=float32), DeviceArray(371648.88, dtype=float32), DeviceArray(1729706.6, dtype=float32), DeviceArray(179295.11, dtype=float32))
# 242
# (DeviceArray(1557592.5, dtype=float32), DeviceArray(365152., dtype=float32), DeviceArray(2341885.8, dtype=float32), DeviceArray(784293.3, dtype=float32))
# 243
# (DeviceArray(1559021.2, dtype=float32), DeviceArray(362985.06, dtype=float32), DeviceArray(2664705.5, dtype=float32), DeviceArray(1105684.1, dtype=float32))
# 244
# (DeviceArray(1555523., dtype=float32), DeviceArray(364689.9, dtype=float32), DeviceArray(2408352., dtype=float32), DeviceArray(852829., dtype=float32))
# 245
# (DeviceArray(1546964.6, dtype=float32), DeviceArray(369886.56, dtype=float32), DeviceArray(1629048.1, dtype=float32), DeviceArray(82083.45, dtype=float32))
# 246
# (DeviceArray(1533312.8, dtype=float32), DeviceArray(378220.47, dtype=float32), DeviceArray(2687278.2, dtype=float32), DeviceArray(1153965.5, dtype=float32))
# 247
# (DeviceArray(1528648.2, dtype=float32), DeviceArray(382121.12, dtype=float32), DeviceArray(3261142., dtype=float32), DeviceArray(1732493.9, dtype=float32))
# 248
# (DeviceArray(1521600.6, dtype=float32), DeviceArray(382034.44, dtype=float32), DeviceArray(3241237.5, dtype=float32), DeviceArray(1719636.8, dtype=float32))
# 249
# (DeviceArray(1526966.1, dtype=float32), DeviceArray(378354.88, dtype=float32), DeviceArray(2700866., dtype=float32), DeviceArray(1173900., dtype=float32))
# 250
# (DeviceArray(1535469.2, dtype=float32), DeviceArray(371452.66, dtype=float32), DeviceArray(1685662., dtype=float32), DeviceArray(150192.8, dtype=float32))
# 251
# (DeviceArray(1544275., dtype=float32), DeviceArray(361655.66, dtype=float32), DeviceArray(2847131., dtype=float32), DeviceArray(1302855.9, dtype=float32))
# 252
# (DeviceArray(1557111., dtype=float32), DeviceArray(356525.34, dtype=float32), DeviceArray(3620872.5, dtype=float32), DeviceArray(2063761.6, dtype=float32))
# 253
# (DeviceArray(1559571., dtype=float32), DeviceArray(355601.16, dtype=float32), DeviceArray(3760404., dtype=float32), DeviceArray(2200833., dtype=float32))
# 254
# (DeviceArray(1545333., dtype=float32), DeviceArray(358454.94, dtype=float32), DeviceArray(3322905.5, dtype=float32), DeviceArray(1777572.6, dtype=float32))
# 255
# (DeviceArray(1532094.2, dtype=float32), DeviceArray(364676.94, dtype=float32), DeviceArray(2386846.8, dtype=float32), DeviceArray(854752.5, dtype=float32))
# 256
# (DeviceArray(1520834.8, dtype=float32), DeviceArray(373928.4, dtype=float32), DeviceArray(2038220., dtype=float32), DeviceArray(517385.3, dtype=float32))
# 257
# (DeviceArray(1515286.8, dtype=float32), DeviceArray(378653.47, dtype=float32), DeviceArray(2733473., dtype=float32), DeviceArray(1218186.1, dtype=float32))
# 258
# (DeviceArray(1514699., dtype=float32), DeviceArray(379304.56, dtype=float32), DeviceArray(2829452.5, dtype=float32), DeviceArray(1314753.5, dtype=float32))
# 259
# (DeviceArray(1512259.8, dtype=float32), DeviceArray(376288.72, dtype=float32), DeviceArray(2379716.5, dtype=float32), DeviceArray(867456.7, dtype=float32))
# 260
# (DeviceArray(1517264.8, dtype=float32), DeviceArray(369983.5, dtype=float32), DeviceArray(1584970.9, dtype=float32), DeviceArray(67706.1, dtype=float32))
# 261
# (DeviceArray(1518807.1, dtype=float32), DeviceArray(367959.62, dtype=float32), DeviceArray(1886685.6, dtype=float32), DeviceArray(367878.5, dtype=float32))
# 262
# (DeviceArray(1515844.5, dtype=float32), DeviceArray(369800.8, dtype=float32), DeviceArray(1610646., dtype=float32), DeviceArray(94801.52, dtype=float32))
# 263
# (DeviceArray(1508585.8, dtype=float32), DeviceArray(375117.88, dtype=float32), DeviceArray(2202388., dtype=float32), DeviceArray(693802.2, dtype=float32))
# 264
# (DeviceArray(1501489., dtype=float32), DeviceArray(376301.2, dtype=float32), DeviceArray(2370795., dtype=float32), DeviceArray(869306., dtype=float32))
# 265
# (DeviceArray(1504052., dtype=float32), DeviceArray(373775.97, dtype=float32), DeviceArray(1998828.5, dtype=float32), DeviceArray(494776.44, dtype=float32))
# 266
# (DeviceArray(1516646.8, dtype=float32), DeviceArray(367912.47, dtype=float32), DeviceArray(1891519.2, dtype=float32), DeviceArray(374872.5, dtype=float32))
# 267
# (DeviceArray(1521244.2, dtype=float32), DeviceArray(366319.3, dtype=float32), DeviceArray(2132406.8, dtype=float32), DeviceArray(611162.56, dtype=float32))
# 268
# (DeviceArray(1508839.2, dtype=float32), DeviceArray(368560.2, dtype=float32), DeviceArray(1787644.9, dtype=float32), DeviceArray(278805.66, dtype=float32))
# 269
# (DeviceArray(1501112.2, dtype=float32), DeviceArray(374236.72, dtype=float32), DeviceArray(2064225.1, dtype=float32), DeviceArray(563112.9, dtype=float32))
# 270
# (DeviceArray(1496877., dtype=float32), DeviceArray(375745.28, dtype=float32), DeviceArray(2283733.5, dtype=float32), DeviceArray(786856.4, dtype=float32))
# 271
# (DeviceArray(1498195.5, dtype=float32), DeviceArray(373509.94, dtype=float32), DeviceArray(1953515.4, dtype=float32), DeviceArray(455319.84, dtype=float32))
# 272
# (DeviceArray(1512495., dtype=float32), DeviceArray(367906.3, dtype=float32), DeviceArray(1888280.5, dtype=float32), DeviceArray(375785.56, dtype=float32))
# 273
# (DeviceArray(1513696.2, dtype=float32), DeviceArray(366545.06, dtype=float32), DeviceArray(2091376.5, dtype=float32), DeviceArray(577680.25, dtype=float32))
# 274
# (DeviceArray(1502656.2, dtype=float32), DeviceArray(368998.66, dtype=float32), DeviceArray(1716430.1, dtype=float32), DeviceArray(213773.88, dtype=float32))
# 275
# (DeviceArray(1492282.4, dtype=float32), DeviceArray(374856.6, dtype=float32), DeviceArray(2147332.5, dtype=float32), DeviceArray(655050.06, dtype=float32))
# 276
# (DeviceArray(1489158.8, dtype=float32), DeviceArray(376527.97, dtype=float32), DeviceArray(2392100., dtype=float32), DeviceArray(902941.2, dtype=float32))
# 277
# (DeviceArray(1491464.8, dtype=float32), DeviceArray(374431.78, dtype=float32), DeviceArray(2083508.5, dtype=float32), DeviceArray(592043.75, dtype=float32))
# 278
# (DeviceArray(1505160.5, dtype=float32), DeviceArray(368943.88, dtype=float32), DeviceArray(1727059.2, dtype=float32), DeviceArray(221898.78, dtype=float32))
# 279
# (DeviceArray(1497591.2, dtype=float32), DeviceArray(367683.4, dtype=float32), DeviceArray(1906437.2, dtype=float32), DeviceArray(408846.06, dtype=float32))
# 280
# (DeviceArray(1495250.2, dtype=float32), DeviceArray(370208.94, dtype=float32), DeviceArray(1529520.5, dtype=float32), DeviceArray(34270.19, dtype=float32))
# 281
# (DeviceArray(1489377.2, dtype=float32), DeviceArray(376129.75, dtype=float32), DeviceArray(2333256.5, dtype=float32), DeviceArray(843879.1, dtype=float32))
# 282
# (DeviceArray(1484018.6, dtype=float32), DeviceArray(377857.12, dtype=float32), DeviceArray(2584094.5, dtype=float32), DeviceArray(1100075.9, dtype=float32))
# 283
# (DeviceArray(1485476.8, dtype=float32), DeviceArray(375809.84, dtype=float32), DeviceArray(2281908.8, dtype=float32), DeviceArray(796432., dtype=float32))
# 284
# (DeviceArray(1493019.4, dtype=float32), DeviceArray(370364.88, dtype=float32), DeviceArray(1504161.6, dtype=float32), DeviceArray(11142.215, dtype=float32))
# 285
# (DeviceArray(1492107.8, dtype=float32), DeviceArray(369123.12, dtype=float32), DeviceArray(1687421., dtype=float32), DeviceArray(195313.2, dtype=float32))
# 286
# (DeviceArray(1487456.5, dtype=float32), DeviceArray(371655.06, dtype=float32), DeviceArray(1667669.2, dtype=float32), DeviceArray(180212.81, dtype=float32))
# 287
# (DeviceArray(1488373.5, dtype=float32), DeviceArray(370342.2, dtype=float32), DeviceArray(1502880.6, dtype=float32), DeviceArray(14507.127, dtype=float32))
# 288
# (DeviceArray(1485093., dtype=float32), DeviceArray(372829.34, dtype=float32), DeviceArray(1839470.1, dtype=float32), DeviceArray(354377.12, dtype=float32))
# 289
# (DeviceArray(1484874.9, dtype=float32), DeviceArray(371464.03, dtype=float32), DeviceArray(1636754.8, dtype=float32), DeviceArray(151879.89, dtype=float32))
# 290
# (DeviceArray(1497287.5, dtype=float32), DeviceArray(366634.62, dtype=float32), DeviceArray(2061684.2, dtype=float32), DeviceArray(564396.75, dtype=float32))
# 291
# (DeviceArray(1492229.4, dtype=float32), DeviceArray(365971.38, dtype=float32), DeviceArray(2154996.5, dtype=float32), DeviceArray(662767.1, dtype=float32))
# 292
# (DeviceArray(1485706., dtype=float32), DeviceArray(369055.84, dtype=float32), DeviceArray(1690998., dtype=float32), DeviceArray(205292.06, dtype=float32))
# 293
# (DeviceArray(1478924.9, dtype=float32), DeviceArray(375484., dtype=float32), DeviceArray(2227029., dtype=float32), DeviceArray(748104.25, dtype=float32))
# 294
# (DeviceArray(1476664., dtype=float32), DeviceArray(377669.2, dtype=float32), DeviceArray(2548866., dtype=float32), DeviceArray(1072201.9, dtype=float32))
# 295
# (DeviceArray(1477686.1, dtype=float32), DeviceArray(376033.62, dtype=float32), DeviceArray(2307308.5, dtype=float32), DeviceArray(829622.25, dtype=float32))
# 296
# (DeviceArray(1480329.8, dtype=float32), DeviceArray(370959.03, dtype=float32), DeviceArray(1557310.2, dtype=float32), DeviceArray(76980.47, dtype=float32))
# 297
# (DeviceArray(1491512.2, dtype=float32), DeviceArray(362829., dtype=float32), DeviceArray(2620343., dtype=float32), DeviceArray(1128830.6, dtype=float32))
# 298
# (DeviceArray(1488407.9, dtype=float32), DeviceArray(359194.62, dtype=float32), DeviceArray(3156273.2, dtype=float32), DeviceArray(1667865.4, dtype=float32))
# 299
# ...
# 1007
# (DeviceArray(1076599.2, dtype=float32), DeviceArray(374618.2, dtype=float32), DeviceArray(1696290., dtype=float32), DeviceArray(619690.7, dtype=float32))
# 1008
# (DeviceArray(1078591.2, dtype=float32), DeviceArray(371243.3, dtype=float32), DeviceArray(1197735.1, dtype=float32), DeviceArray(119143.836, dtype=float32))
# 1009
# (DeviceArray(1082549.9, dtype=float32), DeviceArray(364561.66, dtype=float32), DeviceArray(1954400.4, dtype=float32), DeviceArray(871850.5, dtype=float32))
# 1010
# (DeviceArray(1084240.1, dtype=float32), DeviceArray(362269.7, dtype=float32), DeviceArray(2296025.5, dtype=float32), DeviceArray(1211785.4, dtype=float32))
# 1011
# (DeviceArray(1083016.2, dtype=float32), DeviceArray(363906.3, dtype=float32), DeviceArray(2052064.5, dtype=float32), DeviceArray(969048.25, dtype=float32))
# 1012
# (DeviceArray(1079840.6, dtype=float32), DeviceArray(369059.3, dtype=float32), DeviceArray(1284618.2, dtype=float32), DeviceArray(204777.6, dtype=float32))
# 1013
# (DeviceArray(1074763.4, dtype=float32), DeviceArray(377376.6, dtype=float32), DeviceArray(2103569., dtype=float32), DeviceArray(1028805.56, dtype=float32))
# 1014
# (DeviceArray(1072388.9, dtype=float32), DeviceArray(381211.25, dtype=float32), DeviceArray(2669934., dtype=float32), DeviceArray(1597545.2, dtype=float32))
# 1015
# (DeviceArray(1071979.2, dtype=float32), DeviceArray(381010.56, dtype=float32), DeviceArray(2639759.5, dtype=float32), DeviceArray(1567780.1, dtype=float32))
# 1016
# (DeviceArray(1073874.2, dtype=float32), DeviceArray(377179.2, dtype=float32), DeviceArray(2073401.4, dtype=float32), DeviceArray(999527.1, dtype=float32))
# 1017
# (DeviceArray(1078379.4, dtype=float32), DeviceArray(370079.56, dtype=float32), DeviceArray(1131837.9, dtype=float32), DeviceArray(53458.53, dtype=float32))
# 1018
# (DeviceArray(1078550.1, dtype=float32), DeviceArray(367374.9, dtype=float32), DeviceArray(1533151.5, dtype=float32), DeviceArray(454601.44, dtype=float32))
# 1019
# (DeviceArray(1076201.1, dtype=float32), DeviceArray(368621., dtype=float32), DeviceArray(1345987.4, dtype=float32), DeviceArray(269786.22, dtype=float32))
# 1020
# (DeviceArray(1072451.9, dtype=float32), DeviceArray(373422.5, dtype=float32), DeviceArray(1514803.4, dtype=float32), DeviceArray(442351.5, dtype=float32))
# 1021
# (DeviceArray(1071424.8, dtype=float32), DeviceArray(374092.28, dtype=float32), DeviceArray(1613115.2, dtype=float32), DeviceArray(541690.56, dtype=float32))
# 1022
# (DeviceArray(1073710., dtype=float32), DeviceArray(371048.94, dtype=float32), DeviceArray(1164025., dtype=float32), DeviceArray(90314.98, dtype=float32))
# 1023
# (DeviceArray(1078111.4, dtype=float32), DeviceArray(364663.25, dtype=float32), DeviceArray(1934894., dtype=float32), DeviceArray(856782.56, dtype=float32))
# 1024
# (DeviceArray(1078352.4, dtype=float32), DeviceArray(362634.22, dtype=float32), DeviceArray(2236072., dtype=float32), DeviceArray(1157719.8, dtype=float32))
# 1025
# (DeviceArray(1076967., dtype=float32), DeviceArray(364525.7, dtype=float32), DeviceArray(1954152.2, dtype=float32), DeviceArray(877185.25, dtype=float32))
# 1026
# (DeviceArray(1073100.5, dtype=float32), DeviceArray(369909.44, dtype=float32), DeviceArray(1151791.2, dtype=float32), DeviceArray(78690.734, dtype=float32))
# 1027
# (DeviceArray(1067279., dtype=float32), DeviceArray(378435.53, dtype=float32), DeviceArray(2253141.5, dtype=float32), DeviceArray(1185862.6, dtype=float32))
# 1028
# (DeviceArray(1064723.8, dtype=float32), DeviceArray(382457.62, dtype=float32), DeviceArray(2847126., dtype=float32), DeviceArray(1782402.1, dtype=float32))
# 1029
# (DeviceArray(1063441.1, dtype=float32), DeviceArray(382425.5, dtype=float32), DeviceArray(2841078.5, dtype=float32), DeviceArray(1777637.5, dtype=float32))
# 1030
# (DeviceArray(1065706.6, dtype=float32), DeviceArray(378743.88, dtype=float32), DeviceArray(2297301.5, dtype=float32), DeviceArray(1231594.9, dtype=float32))
# 1031
# (DeviceArray(1070802., dtype=float32), DeviceArray(371779.1, dtype=float32), DeviceArray(1269410.6, dtype=float32), DeviceArray(198608.6, dtype=float32))
# 1032
# (DeviceArray(1078650.2, dtype=float32), DeviceArray(361943., dtype=float32), DeviceArray(2338888.5, dtype=float32), DeviceArray(1260238.2, dtype=float32))
# 1033
# (DeviceArray(1084202.5, dtype=float32), DeviceArray(357207.6, dtype=float32), DeviceArray(3046775.8, dtype=float32), DeviceArray(1962573.2, dtype=float32))
# 1034
# (DeviceArray(1080798.8, dtype=float32), DeviceArray(356688., dtype=float32), DeviceArray(3120436., dtype=float32), DeviceArray(2039637.1, dtype=float32))
# 1035
# (DeviceArray(1078338.2, dtype=float32), DeviceArray(359908.12, dtype=float32), DeviceArray(2640380.5, dtype=float32), DeviceArray(1562042.1, dtype=float32))
# 1036
# (DeviceArray(1072024.5, dtype=float32), DeviceArray(366492.66, dtype=float32), DeviceArray(1657477.5, dtype=float32), DeviceArray(585452.94, dtype=float32))
# 1037
# (DeviceArray(1064672.8, dtype=float32), DeviceArray(376099.12, dtype=float32), DeviceArray(1904009.8, dtype=float32), DeviceArray(839336.94, dtype=float32))
# 1038
# (DeviceArray(1061520.1, dtype=float32), DeviceArray(381098.3, dtype=float32), DeviceArray(2642315., dtype=float32), DeviceArray(1580794.8, dtype=float32))
# 1039
# (DeviceArray(1060612.4, dtype=float32), DeviceArray(381945.3, dtype=float32), DeviceArray(2767030.5, dtype=float32), DeviceArray(1706418.1, dtype=float32))
# 1040
# (DeviceArray(1061941.6, dtype=float32), DeviceArray(379055.06, dtype=float32), DeviceArray(2339690.5, dtype=float32), DeviceArray(1277748.8, dtype=float32))
# 1041
# (DeviceArray(1066550.5, dtype=float32), DeviceArray(372801.38, dtype=float32), DeviceArray(1416779.5, dtype=float32), DeviceArray(350228.94, dtype=float32))
# 1042
# (DeviceArray(1075354., dtype=float32), DeviceArray(363525.7, dtype=float32), DeviceArray(2100855., dtype=float32), DeviceArray(1025500.94, dtype=float32))
# 1043
# (DeviceArray(1081074.4, dtype=float32), DeviceArray(358882.38, dtype=float32), DeviceArray(2795251.5, dtype=float32), DeviceArray(1714177., dtype=float32))
# 1044
# (DeviceArray(1077755.2, dtype=float32), DeviceArray(358423.06, dtype=float32), DeviceArray(2860055.5, dtype=float32), DeviceArray(1782300.1, dtype=float32))
# 1045
# (DeviceArray(1074940.2, dtype=float32), DeviceArray(361707.25, dtype=float32), DeviceArray(2370144., dtype=float32), DeviceArray(1295203.8, dtype=float32))
# 1046
# (DeviceArray(1068761.5, dtype=float32), DeviceArray(368349.2, dtype=float32), DeviceArray(1378861.8, dtype=float32), DeviceArray(310100.25, dtype=float32))
# 1047
# (DeviceArray(1062772.5, dtype=float32), DeviceArray(378007.4, dtype=float32), DeviceArray(2185137.5, dtype=float32), DeviceArray(1122365., dtype=float32))
# 1048
# (DeviceArray(1059641.2, dtype=float32), DeviceArray(383048., dtype=float32), DeviceArray(2929605.2, dtype=float32), DeviceArray(1869964., dtype=float32))
# 1049
# (DeviceArray(1058029.1, dtype=float32), DeviceArray(383932.2, dtype=float32), DeviceArray(3059132., dtype=float32), DeviceArray(2001102.9, dtype=float32))
# 1050
# (DeviceArray(1059284.8, dtype=float32), DeviceArray(381078.8, dtype=float32), DeviceArray(2637187.5, dtype=float32), DeviceArray(1577902.6, dtype=float32))
# 1051
# (DeviceArray(1063895.8, dtype=float32), DeviceArray(374857.97, dtype=float32), DeviceArray(1719149.8, dtype=float32), DeviceArray(655254., dtype=float32))
# 1052
# (DeviceArray(1071201.9, dtype=float32), DeviceArray(365611.28, dtype=float32), DeviceArray(1787376.5, dtype=float32), DeviceArray(716174.7, dtype=float32))
# 1053
# (DeviceArray(1075410.4, dtype=float32), DeviceArray(360975.47, dtype=float32), DeviceArray(2479148.8, dtype=float32), DeviceArray(1403738.4, dtype=float32))
# 1054
# (DeviceArray(1075194.2, dtype=float32), DeviceArray(360503., dtype=float32), DeviceArray(2549007., dtype=float32), DeviceArray(1473812.9, dtype=float32))
# 1055
# (DeviceArray(1072107.4, dtype=float32), DeviceArray(363774.84, dtype=float32), DeviceArray(2060654.5, dtype=float32), DeviceArray(988547.1, dtype=float32))
# 1056
# (DeviceArray(1066032., dtype=float32), DeviceArray(370405.12, dtype=float32), DeviceArray(1071204.5, dtype=float32), DeviceArray(5172.5093, dtype=float32))
# 1057
# (DeviceArray(1057937.2, dtype=float32), DeviceArray(380058.62, dtype=float32), DeviceArray(2484530., dtype=float32), DeviceArray(1426592.9, dtype=float32))
# 1058
# (DeviceArray(1055134.5, dtype=float32), DeviceArray(385098.88, dtype=float32), DeviceArray(3229275.5, dtype=float32), DeviceArray(2174141., dtype=float32))
# 1059
# (DeviceArray(1054013., dtype=float32), DeviceArray(385981.56, dtype=float32), DeviceArray(3359070.2, dtype=float32), DeviceArray(2305057.2, dtype=float32))
# 1060
# (DeviceArray(1056088.4, dtype=float32), DeviceArray(383123.3, dtype=float32), DeviceArray(2937222.5, dtype=float32), DeviceArray(1881134., dtype=float32))
# 1061
# (DeviceArray(1059601.2, dtype=float32), DeviceArray(376902.7, dtype=float32), DeviceArray(2018119.1, dtype=float32), DeviceArray(958517.9, dtype=float32))
# 1062
# (DeviceArray(1067751.6, dtype=float32), DeviceArray(367655.4, dtype=float32), DeviceArray(1480750.5, dtype=float32), DeviceArray(412998.9, dtype=float32))
# 1063
# (DeviceArray(1070594.8, dtype=float32), DeviceArray(363028.72, dtype=float32), DeviceArray(2169804., dtype=float32), DeviceArray(1099209.1, dtype=float32))
# 1064
# (DeviceArray(1068022.2, dtype=float32), DeviceArray(362551.06, dtype=float32), DeviceArray(2238075.5, dtype=float32), DeviceArray(1170053.1, dtype=float32))
# 1065
# (DeviceArray(1065998.5, dtype=float32), DeviceArray(365803.5, dtype=float32), DeviceArray(1753664.1, dtype=float32), DeviceArray(687665.6, dtype=float32))
# 1066
# (DeviceArray(1062221.5, dtype=float32), DeviceArray(372411.97, dtype=float32), DeviceArray(1354695.4, dtype=float32), DeviceArray(292473.88, dtype=float32))
# 1067
# (DeviceArray(1059946.5, dtype=float32), DeviceArray(374706.3, dtype=float32), DeviceArray(1692707.5, dtype=float32), DeviceArray(632761., dtype=float32))
# 1068
# (DeviceArray(1060637.1, dtype=float32), DeviceArray(373118.5, dtype=float32), DeviceArray(1457900.6, dtype=float32), DeviceArray(397263.53, dtype=float32))
# 1069
# (DeviceArray(1063335.9, dtype=float32), DeviceArray(368036.12, dtype=float32), DeviceArray(1419868.2, dtype=float32), DeviceArray(356532.34, dtype=float32))
# 1070
# (DeviceArray(1064148.9, dtype=float32), DeviceArray(367144.06, dtype=float32), DeviceArray(1552988., dtype=float32), DeviceArray(488839.2, dtype=float32))
# 1071
# (DeviceArray(1062226.8, dtype=float32), DeviceArray(370027.3, dtype=float32), DeviceArray(1123434.8, dtype=float32), DeviceArray(61208.023, dtype=float32))
# 1072
# (DeviceArray(1056929.4, dtype=float32), DeviceArray(376303.5, dtype=float32), DeviceArray(1926578.2, dtype=float32), DeviceArray(869648.94, dtype=float32))
# 1073
# (DeviceArray(1054817.2, dtype=float32), DeviceArray(378299.2, dtype=float32), DeviceArray(2220458., dtype=float32), DeviceArray(1165640.8, dtype=float32))
# 1074
# (DeviceArray(1054464.2, dtype=float32), DeviceArray(376447.5, dtype=float32), DeviceArray(1945470.8, dtype=float32), DeviceArray(891006.44, dtype=float32))
# 1075
# (DeviceArray(1058337.2, dtype=float32), DeviceArray(371127.47, dtype=float32), DeviceArray(1160299.6, dtype=float32), DeviceArray(101962.39, dtype=float32))
# 1076
# (DeviceArray(1068751.6, dtype=float32), DeviceArray(362693.5, dtype=float32), DeviceArray(2217679., dtype=float32), DeviceArray(1148927.4, dtype=float32))
# 1077
# (DeviceArray(1068686.6, dtype=float32), DeviceArray(358826.66, dtype=float32), DeviceArray(2791127.5, dtype=float32), DeviceArray(1722440.9, dtype=float32))
# 1078
# (DeviceArray(1067517.8, dtype=float32), DeviceArray(359054.25, dtype=float32), DeviceArray(2756203., dtype=float32), DeviceArray(1688685.1, dtype=float32))
# 1079
# (DeviceArray(1062572.6, dtype=float32), DeviceArray(362955.06, dtype=float32), DeviceArray(2172706., dtype=float32), DeviceArray(1110133.5, dtype=float32))
# 1080
# (DeviceArray(1056513.5, dtype=float32), DeviceArray(370148.25, dtype=float32), DeviceArray(1099784.6, dtype=float32), DeviceArray(43271.098, dtype=float32))
# 1081
# (DeviceArray(1049912.2, dtype=float32), DeviceArray(380309.56, dtype=float32), DeviceArray(2513723., dtype=float32), DeviceArray(1463810.9, dtype=float32))
# 1082
# (DeviceArray(1046722.2, dtype=float32), DeviceArray(385800.56, dtype=float32), DeviceArray(3324934.5, dtype=float32), DeviceArray(2278212.2, dtype=float32))
# 1083
# (DeviceArray(1045183.2, dtype=float32), DeviceArray(387088.56, dtype=float32), DeviceArray(3514426., dtype=float32), DeviceArray(2469242.8, dtype=float32))
# 1084
# (DeviceArray(1046617.25, dtype=float32), DeviceArray(384594.44, dtype=float32), DeviceArray(3145942.2, dtype=float32), DeviceArray(2099325., dtype=float32))
# 1085
# (DeviceArray(1049930.8, dtype=float32), DeviceArray(378696.06, dtype=float32), DeviceArray(2274434.2, dtype=float32), DeviceArray(1224503.5, dtype=float32))
# 1086
# (DeviceArray(1056568.5, dtype=float32), DeviceArray(369738.22, dtype=float32), DeviceArray(1160653.6, dtype=float32), DeviceArray(104085.16, dtype=float32))
# 1087
# (DeviceArray(1059897.5, dtype=float32), DeviceArray(365362.62, dtype=float32), DeviceArray(1812951.8, dtype=float32), DeviceArray(753054.3, dtype=float32))
# 1088
# (DeviceArray(1059815.8, dtype=float32), DeviceArray(365111., dtype=float32), DeviceArray(1850190., dtype=float32), DeviceArray(790374.25, dtype=float32))
# 1089
# (DeviceArray(1055673.2, dtype=float32), DeviceArray(368570., dtype=float32), DeviceArray(1333023.5, dtype=float32), DeviceArray(277350.3, dtype=float32))
# 1090
# (DeviceArray(1051520.8, dtype=float32), DeviceArray(375369.84, dtype=float32), DeviceArray(1782693.9, dtype=float32), DeviceArray(731173.1, dtype=float32))
# 1091
# (DeviceArray(1048696.5, dtype=float32), DeviceArray(377835.9, dtype=float32), DeviceArray(2145625.5, dtype=float32), DeviceArray(1096928.9, dtype=float32))
# 1092
# (DeviceArray(1048977.8, dtype=float32), DeviceArray(376405.94, dtype=float32), DeviceArray(1933819.8, dtype=float32), DeviceArray(884842.06, dtype=float32))
# 1093
# (DeviceArray(1052720.9, dtype=float32), DeviceArray(371464.7, dtype=float32), DeviceArray(1204698.1, dtype=float32), DeviceArray(151977.22, dtype=float32))
# 1094
# (DeviceArray(1060912.2, dtype=float32), DeviceArray(363377.75, dtype=float32), DeviceArray(2108354.5, dtype=float32), DeviceArray(1047442.4, dtype=float32))
# 1095
# (DeviceArray(1062882.5, dtype=float32), DeviceArray(359799.88, dtype=float32), DeviceArray(2640979.8, dtype=float32), DeviceArray(1578097.2, dtype=float32))
# 1096
# (DeviceArray(1061671.8, dtype=float32), DeviceArray(360282.25, dtype=float32), DeviceArray(2568225.2, dtype=float32), DeviceArray(1506553.5, dtype=float32))
# 1097
# (DeviceArray(1058428.8, dtype=float32), DeviceArray(364413.75, dtype=float32), DeviceArray(1952216., dtype=float32), DeviceArray(893787.3, dtype=float32))
# 1098
# (DeviceArray(1052199., dtype=float32), DeviceArray(371819.62, dtype=float32), DeviceArray(1256819., dtype=float32), DeviceArray(204620.02, dtype=float32))
# 1099
# (DeviceArray(1049939.9, dtype=float32), DeviceArray(374836.47, dtype=float32), DeviceArray(1702005.1, dtype=float32), DeviceArray(652065.25, dtype=float32))
# 1100
# (DeviceArray(1050541.2, dtype=float32), DeviceArray(373898., dtype=float32), DeviceArray(1563416.9, dtype=float32), DeviceArray(512875.6, dtype=float32))
# 1101
# (DeviceArray(1053003.5, dtype=float32), DeviceArray(369403.5, dtype=float32), DeviceArray(1206732.8, dtype=float32), DeviceArray(153729.2, dtype=float32))
# 1102
# (DeviceArray(1052244.8, dtype=float32), DeviceArray(369041.12, dtype=float32), DeviceArray(1259719.9, dtype=float32), DeviceArray(207475.1, dtype=float32))
# 1103
# (DeviceArray(1049803.2, dtype=float32), DeviceArray(372396.88, dtype=float32), DeviceArray(1340038.5, dtype=float32), DeviceArray(290235.22, dtype=float32))
# 1104
# (DeviceArray(1049695.8, dtype=float32), DeviceArray(371762.78, dtype=float32), DeviceArray(1245885., dtype=float32), DeviceArray(196189.19, dtype=float32))
# 1105
# (DeviceArray(1052853.1, dtype=float32), DeviceArray(367542.44, dtype=float32), DeviceArray(1482607., dtype=float32), DeviceArray(429753.94, dtype=float32))
# 1106

# %%
baseline_trials = 20
T_prev_baseline = np.ones_like(T_prev, dtype=float) * baseline_trials

probs_empirical_baseline = sample_spikes_array(probs_true_scan, T_prev_baseline, NUM_THREADS=24)

w_inits_array_baseline = np.zeros((probs_empirical_baseline.shape[0], probs_empirical_baseline.shape[1]), dtype=object)
for i in range(len(w_inits_array_baseline)):
    for j in range(len(w_inits_array_baseline[i])):
        w_inits = []

        for m in ms:
            w_init = np.array(np.random.normal(size=(m, amps_scan[j].shape[1]+1)))
            w_inits.append(w_init)

        w_inits_array_baseline[i][j] = w_inits

input_list_baseline = fitting.generate_input_list(probs_empirical_baseline, amps_scan, T_prev_baseline, w_inits_array_baseline, 1 / baseline_trials,
                                                    disambiguate=disambiguate)

pool = mp.Pool(processes=24)
results_baseline = pool.starmap_async(fitting.fit_surface, input_list_baseline)
mp_output_baseline = results_baseline.get()
pool.close()

params_curr_baseline = np.zeros((probs_empirical_baseline.shape[0], probs_empirical_baseline.shape[1]), dtype=object)
w_inits_array_baseline = np.zeros((probs_empirical_baseline.shape[0], probs_empirical_baseline.shape[1]), dtype=object)
probs_curr_baseline = np.zeros(probs_empirical_baseline.shape)

cnt = 0
for i in range(len(probs_empirical_baseline)):
    for j in range(len(probs_empirical_baseline[i])):
        params_curr_baseline[i][j] = mp_output_baseline[cnt][0]
        w_inits_array_baseline[i][j] = mp_output_baseline[cnt][1]
        
        probs_curr_baseline[i][j] = fitting.sigmoidND_nonlinear(
                                sm.add_constant(amps_scan[j], has_constant='add'), 
                                params_curr_baseline[i][j])

        cnt += 1

performance_baseline = get_performance_array(params_true, probs_curr_baseline, probs_true_scan)

# %%
plt.figure(figsize=(10, 8))

plt.plot(np.array(num_samples)/T_prev.shape[0]/T_prev.shape[1], performances, linewidth=4, c='tab:blue', label='Optimal Sampling')
plt.plot(np.array(num_samples_uniform)/T_prev_uniform.shape[0]/T_prev_uniform.shape[1], performances_uniform, linewidth=4, c='tab:red', label='Uniform Sampling')

plt.axhline(performance_baseline, c='k', linestyle='--', linewidth=2, label=f'{baseline_trials} Uniform Trials')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Average Trials per Current Level', fontsize=24)
plt.ylabel(r'RMSE', fontsize=24)
plt.legend(fontsize=20)

# plt.savefig(f'triplet_AL_full_{dataset}.png', dpi=300)

# %%
# CHECK DATASET IF NEEDED
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(probs_true_scan)):
    for j in range(len(probs_true_scan[i])):
        if type(params_true[i][j]) != int:

            print(params_true[i][j])
            sampled_inds = np.where(T_prev[j] > 0)[0]
            
            fig = plt.figure(0)
            fig.clear()
            ax = Axes3D(fig, auto_add_to_figure=False)
            fig.add_axes(ax)
            plt.xlabel(r'$I_1$ ($\mu$A)', fontsize=16)
            plt.ylabel(r'$I_2$ ($\mu$A)', fontsize=16)
            plt.xlim(-1.8, 1.8)
            plt.ylim(-1.8, 1.8)
            ax.set_zlim(-1.8, 1.8)
            ax.set_zlabel(r'$I_3$ ($\mu$A)', fontsize=16)

            scat = ax.scatter(amps_scan[j][:, 0], 
                              amps_scan[j][:, 1],
                              amps_scan[j][:, 2], marker='o', 
                              c=probs_true_scan[i][j], s=20, alpha=0.8, vmin=0, vmax=1)
            plt.show()


            print(params_curr[i][j])
            fig = plt.figure(1)
            fig.clear()
            ax = Axes3D(fig, auto_add_to_figure=False)
            fig.add_axes(ax)
            plt.xlabel(r'$I_1$ ($\mu$A)', fontsize=16)
            plt.ylabel(r'$I_2$ ($\mu$A)', fontsize=16)
            plt.xlim(-1.8, 1.8)
            plt.ylim(-1.8, 1.8)
            ax.set_zlim(-1.8, 1.8)
            ax.set_zlabel(r'$I_3$ ($\mu$A)', fontsize=16)

            scat = ax.scatter(amps_scan[j][:, 0], 
                              amps_scan[j][:, 1],
                              amps_scan[j][:, 2], marker='o', 
                              c=probs_curr[i][j], s=20, alpha=0.8, vmin=0, vmax=1)
            plt.show()

            fig = plt.figure(1)
            fig.clear()
            ax = Axes3D(fig, auto_add_to_figure=False)
            fig.add_axes(ax)
            plt.xlabel(r'$I_1$ ($\mu$A)', fontsize=16)
            plt.ylabel(r'$I_2$ ($\mu$A)', fontsize=16)
            plt.xlim(-1.8, 1.8)
            plt.ylim(-1.8, 1.8)
            ax.set_zlim(-1.8, 1.8)
            ax.set_zlabel(r'$I_3$ ($\mu$A)', fontsize=16)

            scat = ax.scatter(amps_scan[j][sampled_inds, 0], 
                              amps_scan[j][sampled_inds, 1],
                              amps_scan[j][sampled_inds, 2], marker='o', 
                              c=probs_empirical[i][j][sampled_inds], s=20, alpha=0.8, vmin=0, vmax=1)
            plt.show()

            input()
