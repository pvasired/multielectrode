# %%
import os
os.environ["OMP_NUM_THREADS"] = "1" # export OMP_NUM_THREADS=1
os.environ["OPENBLAS_NUM_THREADS"] = "1" # export OPENBLAS_NUM_THREADS=1
os.environ["MKL_NUM_THREADS"] = "1" # export MKL_NUM_THREADS=1
os.environ["VECLIB_MAXIMUM_THREADS"] = "1" # export VECLIB_MAXIMUM_THREADS=1
os.environ["NUMEXPR_NUM_THREADS"] = "1" # export NUMEXPR_NUM_THREADS=1
os.environ["CUDA_VISIBLE_DEVICES"]= '3'

import numpy as np
import matplotlib.pyplot as plt
import multielec_src.fitting as fitting
import multielec_src.multielec_utils as mutils
from scipy.io import loadmat
import multiprocessing as mp
import statsmodels.api as sm
from copy import deepcopy, copy
import visionloader as vl
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def sample_spikes(p_true, t):
    p_true, t = np.array(p_true), np.array(t).astype(int)
    
    p_empirical = []
    for i in range(len(p_true)):
        if t[i] == 0:
            p_empirical += [0.5]
        
        else:
            p_empirical += [np.mean(np.random.choice(np.array([0, 1]), 
                                                 p=np.array([1-p_true[i], p_true[i]]), 
                                                 size=t[i]))]
        
    p_empirical_array = np.array(p_empirical)

    return p_empirical_array

# %%
def sample_spikes_array(true_probs, trials, NUM_THREADS=24):

    input_list = []
    for i in range(len(true_probs)):
        for j in range(len(true_probs[i])):
            input_list += [(true_probs[i][j], trials[j])]
            
    pool = mp.Pool(processes=NUM_THREADS)
    results = pool.starmap_async(sample_spikes, input_list)
    mp_output = results.get()
    pool.close()

    return np.array(mp_output).reshape(true_probs.shape)

# %%
def get_performance_array(true_params, curr_probs, true_probs):
    
    error = 0
    cnt = 0
    for i in range(len(true_params)):
        for j in range(len(true_params[i])):
            if type(true_params[i][j]) != int:
                error += np.sqrt(np.sum((curr_probs[i][j] - true_probs[i][j])**2) / len(true_probs[i][j]))
                cnt += 1

    return error / cnt

# %%
NUM_CELLS = 30
NUM_PATTERNS = 10
ms = [1, 2, 3, 4]
cell_positions = np.random.choice(NUM_PATTERNS, size=NUM_CELLS, replace=True)
bias_mean = -8
bias_var = 2
slope_var = 5
slope_bound = 10
zero_prob = 0.01

amps_scan = np.array([np.array(np.meshgrid(np.linspace(-2, 2, 21), 
                                np.linspace(-2, 2, 21),
                                np.linspace(-2, 2, 21))).T.reshape(-1,3)] * NUM_PATTERNS)

params_true = np.zeros((NUM_CELLS, NUM_PATTERNS), dtype=object)
probs_true_scan = np.zeros((NUM_CELLS, NUM_PATTERNS, amps_scan.shape[1]))

for i in range(len(cell_positions)):
    m = np.random.choice(np.array(ms))
    j = cell_positions[i]
    
    params = np.zeros((m, amps_scan[j].shape[1]+1))
    for l in range(m):
        params[l, :] = np.random.normal(np.random.choice([-5, 5]), slope_var, size=amps_scan[j].shape[1]+1)

    params[:, 0] = np.random.normal(bias_mean, bias_var, len(params[:, 0]))
    z = 1 - (1 - zero_prob)**(1/m)
    params[:, 0][params[:, 0] > np.log(z/(1-z))] = np.log(z/(1-z))
    params[:, 1:][params[:, 1:] > slope_bound] = slope_bound
    params[:, 1:][params[:, 1:] < -slope_bound] = -slope_bound
    params_true[i][j] = params

for i in range(len(probs_true_scan)):
    for j in range(len(probs_true_scan[i])):
        if type(params_true[i][j]) != int:
            probs_true_scan[i][j] = fitting.sigmoidND_nonlinear(
                                    sm.add_constant(amps_scan[j], has_constant='add'), 
                                    params_true[i][j])
        else:
            probs_true_scan[i][j] = np.zeros(amps_scan.shape[1])

# %%
# CHECK DATASET IF NEEDED
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(probs_true_scan)):
    for j in range(len(probs_true_scan[i])):
        if type(params_true[i][j]) != int:

            print(params_true[i][j])
            
            fig = plt.figure(0)
            fig.clear()
            ax = Axes3D(fig, auto_add_to_figure=False)
            fig.add_axes(ax)
            plt.xlabel(r'$I_1$ ($\mu$A)', fontsize=16)
            plt.ylabel(r'$I_2$ ($\mu$A)', fontsize=16)
            plt.xlim(-1.8, 1.8)
            plt.ylim(-1.8, 1.8)
            ax.set_zlim(-1.8, 1.8)
            ax.set_zlabel(r'$I_3$ ($\mu$A)', fontsize=16)

            scat = ax.scatter(amps_scan[j][:, 0], 
                              amps_scan[j][:, 1],
                              amps_scan[j][:, 2], marker='o', 
                              c=probs_true_scan[i][j], s=20, alpha=0.8, vmin=0, vmax=1)
            plt.show()

            input()

# %%
num_iters = 5

T_prev = np.zeros((amps_scan.shape[0], amps_scan.shape[1]), dtype=float)
budget = T_prev.shape[0] * T_prev.shape[1] * 0.15 #int(total_budget / num_iters)
reg = None # 20, 50
T_step_size = 0.1 # 0.05, 0.01
T_n_steps = 1000    # 5000

init_trials = 5
init_amps = 50
ms = [1, 2, 3, 4]
disambiguate = True
verbose = True
R2_cutoff = 0
prob_low = 1 / init_trials
min_inds = 5
exploit_factor = 1.0

for i in range(len(T_prev)):
    init_inds = np.random.choice(np.arange(len(T_prev[i]), dtype=int), size=init_amps,
                                 replace=False)
    T_prev[i][init_inds] = init_trials

T_prev_uniform = deepcopy(T_prev)

probs_empirical = sample_spikes_array(probs_true_scan, T_prev, NUM_THREADS=24)
probs_empirical_uniform = deepcopy(probs_empirical)

performances = []
performances_uniform = []
num_samples = []
num_samples_uniform = []

iter_cnt = 0
while True:
    if iter_cnt == 0:
        T_new, w_inits_array, t_final, probs_curr, params_curr = fitting.fisher_sampling_1elec(
                                        probs_empirical, 
                                        T_prev, amps_scan,
                                        T_step_size=T_step_size,
                                        T_n_steps=T_n_steps,
                                        verbose=verbose, budget=budget, ms=ms, reg=reg,
                                        return_probs=True,
                                        disambiguate=disambiguate,
                                        R2_cutoff=R2_cutoff,
                                        min_prob=prob_low,
                                        min_inds=min_inds,
                                        exploit_factor=exploit_factor)

        performance = get_performance_array(params_true, probs_curr, probs_true_scan)
        performance_uniform = performance

        w_inits_array_uniform = deepcopy(w_inits_array)
        
    else:
        T_new, w_inits_array, t_final, probs_curr, params_curr = fitting.fisher_sampling_1elec(
                                        probs_empirical, 
                                        T_prev, amps_scan,
                                        T_step_size=T_step_size,
                                        T_n_steps=T_n_steps,
                                        verbose=verbose, budget=budget, ms=ms, reg=reg,
                                        return_probs=True,
                                        # t_final=t_final,
                                        w_inits_array=w_inits_array,
                                        disambiguate=disambiguate,
                                        R2_cutoff=R2_cutoff,
                                        min_prob=prob_low,
                                        min_inds=min_inds,
                                        exploit_factor=exploit_factor)

        
        performance = get_performance_array(params_true, probs_curr, probs_true_scan)

        input_list_uniform = fitting.generate_input_list(probs_empirical_uniform, amps_scan, 
                                                            T_prev_uniform, w_inits_array_uniform, prob_low,
                                                            disambiguate=disambiguate, min_inds=min_inds)

        pool = mp.Pool(processes=24)
        results_uniform = pool.starmap_async(fitting.fit_surface, input_list_uniform)
        mp_output_uniform = results_uniform.get()
        pool.close()

        params_curr_uniform = np.zeros((probs_empirical_uniform.shape[0], probs_empirical_uniform.shape[1]), dtype=object)
        w_inits_array_uniform = np.zeros((probs_empirical_uniform.shape[0], probs_empirical_uniform.shape[1]), dtype=object)
        probs_curr_uniform = np.zeros(probs_empirical_uniform.shape)

        cnt = 0
        for i in range(len(probs_empirical_uniform)):
            for j in range(len(probs_empirical_uniform[i])):
                params_curr_uniform[i][j] = mp_output_uniform[cnt][0]
                w_inits_array_uniform[i][j] = mp_output_uniform[cnt][1]
                
                probs_curr_uniform[i][j] = fitting.sigmoidND_nonlinear(
                                        sm.add_constant(amps_scan[j], has_constant='add'), 
                                        params_curr_uniform[i][j])

                cnt += 1

        performance_uniform = get_performance_array(params_true, probs_curr_uniform, probs_true_scan)
    
    print(performance, performance_uniform)
    
    performances.append(performance)
    performances_uniform.append(performance_uniform)
    
    num_samples.append(np.sum(T_prev))
    num_samples_uniform.append(np.sum(T_prev_uniform))

    iter_cnt += 1

    if iter_cnt > num_iters:
        break

    p_new = sample_spikes_array(probs_true_scan, T_new, NUM_THREADS=24)
    p_tmp = (p_new * T_new[np.newaxis, :, :] + probs_empirical * T_prev[np.newaxis, :, :]) / ((T_new + T_prev)[np.newaxis, :, :])
    T_tmp = T_new + T_prev

    p_tmp = np.nan_to_num(p_tmp, nan=0.5)

    probs_empirical = p_tmp
    T_prev = T_tmp
    
    # random_extra = np.random.choice(len(T_new.flatten()), size=int(np.sum(T_new)), replace=True)
    # T_new_uniform = np.array(np.bincount(random_extra, minlength=len(T_new.flatten())).astype(int).reshape(T_new.shape), dtype=float)
    T_new_uniform = np.ones_like(T_prev_uniform, dtype=float)
    p_new_uniform = sample_spikes_array(probs_true_scan, T_new_uniform, NUM_THREADS=24)

    p_tmp_uniform = (p_new_uniform * T_new_uniform[np.newaxis, :, :] + probs_empirical_uniform * T_prev_uniform[np.newaxis, :, :]) / ((T_prev_uniform + T_new_uniform)[np.newaxis, :, :])
    T_tmp_uniform = T_prev_uniform + T_new_uniform

    p_tmp_uniform = np.nan_to_num(p_tmp_uniform, nan=0.5)

    probs_empirical_uniform = p_tmp_uniform
    T_prev_uniform = T_tmp_uniform
# Out:
# Setting up data...
# Fitting dataset...
# Calculating Jacobian...
# Optimizing trials...
# 0
# (DeviceArray(2289104.5, dtype=float32), DeviceArray(23151.799, dtype=float32), DeviceArray(3948954.5, dtype=float32), DeviceArray(1659850.1, dtype=float32))
# 1
# (DeviceArray(1874799.2, dtype=float32), DeviceArray(23117.488, dtype=float32), DeviceArray(3528499.5, dtype=float32), DeviceArray(1653700.1, dtype=float32))
# 2
# (DeviceArray(2104499., dtype=float32), DeviceArray(20215.781, dtype=float32), DeviceArray(3238086.5, dtype=float32), DeviceArray(1133587.5, dtype=float32))
# 3
# (DeviceArray(2726294., dtype=float32), DeviceArray(16493.664, dtype=float32), DeviceArray(3192715.5, dtype=float32), DeviceArray(466421.47, dtype=float32))
# 4
# (DeviceArray(2486966.2, dtype=float32), DeviceArray(17595.959, dtype=float32), DeviceArray(3150967., dtype=float32), DeviceArray(664000.9, dtype=float32))
# 5
# (DeviceArray(2128445.5, dtype=float32), DeviceArray(17239.592, dtype=float32), DeviceArray(2728569.8, dtype=float32), DeviceArray(600124.3, dtype=float32))
# 6
# (DeviceArray(2296468.5, dtype=float32), DeviceArray(16629.25, dtype=float32), DeviceArray(2787193., dtype=float32), DeviceArray(490724.4, dtype=float32))
# 7
# (DeviceArray(2295157., dtype=float32), DeviceArray(16434.504, dtype=float32), DeviceArray(2750974.5, dtype=float32), DeviceArray(455817.38, dtype=float32))
# 8
# (DeviceArray(2408879., dtype=float32), DeviceArray(15748.718, dtype=float32), DeviceArray(2741773.5, dtype=float32), DeviceArray(332894.56, dtype=float32))
# 9
# (DeviceArray(1930679.2, dtype=float32), DeviceArray(15253.147, dtype=float32), DeviceArray(2174746., dtype=float32), DeviceArray(244066.7, dtype=float32))
# 10
# (DeviceArray(1796608., dtype=float32), DeviceArray(15573.94, dtype=float32), DeviceArray(2098174.8, dtype=float32), DeviceArray(301566.8, dtype=float32))
# 11
# (DeviceArray(1723561.6, dtype=float32), DeviceArray(15257.295, dtype=float32), DeviceArray(1968371.8, dtype=float32), DeviceArray(244810.11, dtype=float32))
# 12
# (DeviceArray(2146567., dtype=float32), DeviceArray(14428.215, dtype=float32), DeviceArray(2242769.8, dtype=float32), DeviceArray(96202.74, dtype=float32))
# 13
# (DeviceArray(2180257.5, dtype=float32), DeviceArray(14410.351, dtype=float32), DeviceArray(2273258.2, dtype=float32), DeviceArray(93000.69, dtype=float32))
# 14
# (DeviceArray(1770580.2, dtype=float32), DeviceArray(14248.244, dtype=float32), DeviceArray(1834524.4, dtype=float32), DeviceArray(63944.133, dtype=float32))
# 15
# (DeviceArray(1541737.5, dtype=float32), DeviceArray(14153.077, dtype=float32), DeviceArray(1588623.5, dtype=float32), DeviceArray(46886.05, dtype=float32))
# 16
# (DeviceArray(1542507.8, dtype=float32), DeviceArray(14319.211, dtype=float32), DeviceArray(1619172.2, dtype=float32), DeviceArray(76664.484, dtype=float32))
# 17
# (DeviceArray(1528055.5, dtype=float32), DeviceArray(15160.383, dtype=float32), DeviceArray(1755494.8, dtype=float32), DeviceArray(227439.23, dtype=float32))
# 18
# (DeviceArray(1436500.6, dtype=float32), DeviceArray(15800.307, dtype=float32), DeviceArray(1778642.1, dtype=float32), DeviceArray(342141.53, dtype=float32))
# 19
# (DeviceArray(1355343.4, dtype=float32), DeviceArray(16096.206, dtype=float32), DeviceArray(1750523., dtype=float32), DeviceArray(395179.62, dtype=float32))
# 20
# (DeviceArray(1191030.1, dtype=float32), DeviceArray(16009.232, dtype=float32), DeviceArray(1570620.2, dtype=float32), DeviceArray(379590.16, dtype=float32))
# 21
# (DeviceArray(1171993.1, dtype=float32), DeviceArray(15714.516, dtype=float32), DeviceArray(1498757.1, dtype=float32), DeviceArray(326764.03, dtype=float32))
# 22
# (DeviceArray(1167628.8, dtype=float32), DeviceArray(15920.355, dtype=float32), DeviceArray(1531288.2, dtype=float32), DeviceArray(363659.53, dtype=float32))
# 23
# (DeviceArray(1197486.1, dtype=float32), DeviceArray(15721.49, dtype=float32), DeviceArray(1525500.2, dtype=float32), DeviceArray(328014.2, dtype=float32))
# 24
# (DeviceArray(1170085.5, dtype=float32), DeviceArray(15505.674, dtype=float32), DeviceArray(1459416., dtype=float32), DeviceArray(289330.47, dtype=float32))
# 25
# (DeviceArray(1181478.2, dtype=float32), DeviceArray(15308.762, dtype=float32), DeviceArray(1435513.5, dtype=float32), DeviceArray(254035.2, dtype=float32))
# 26
# (DeviceArray(1207310., dtype=float32), DeviceArray(15031.441, dtype=float32), DeviceArray(1411637.2, dtype=float32), DeviceArray(204327.3, dtype=float32))
# 27
# (DeviceArray(1122028.2, dtype=float32), DeviceArray(14863.09, dtype=float32), DeviceArray(1296179.6, dtype=float32), DeviceArray(174151.34, dtype=float32))
# 28
# (DeviceArray(1139261.4, dtype=float32), DeviceArray(15134.153, dtype=float32), DeviceArray(1361999.1, dtype=float32), DeviceArray(222737.75, dtype=float32))
# 29
# (DeviceArray(1135513.6, dtype=float32), DeviceArray(15130.415, dtype=float32), DeviceArray(1357581.2, dtype=float32), DeviceArray(222067.69, dtype=float32))
# 30
# (DeviceArray(1153605.2, dtype=float32), DeviceArray(15139.805, dtype=float32), DeviceArray(1377356., dtype=float32), DeviceArray(223750.73, dtype=float32))
# 31
# (DeviceArray(1149199.8, dtype=float32), DeviceArray(15054.937, dtype=float32), DeviceArray(1357738.4, dtype=float32), DeviceArray(208538.64, dtype=float32))
# 32
# (DeviceArray(1147658.6, dtype=float32), DeviceArray(14671.451, dtype=float32), DeviceArray(1287460., dtype=float32), DeviceArray(139801.33, dtype=float32))
# 33
# (DeviceArray(1149624.1, dtype=float32), DeviceArray(14725.893, dtype=float32), DeviceArray(1299183.8, dtype=float32), DeviceArray(149559.6, dtype=float32))
# 34
# (DeviceArray(1157616.6, dtype=float32), DeviceArray(14496.592, dtype=float32), DeviceArray(1266075.5, dtype=float32), DeviceArray(108458.88, dtype=float32))
# 35
# (DeviceArray(1166533.8, dtype=float32), DeviceArray(14222.244, dtype=float32), DeviceArray(1225817.5, dtype=float32), DeviceArray(59283.797, dtype=float32))
# 36
# (DeviceArray(1157735.6, dtype=float32), DeviceArray(13789.699, dtype=float32), DeviceArray(1175982.8, dtype=float32), DeviceArray(18247.146, dtype=float32))
# 37
# (DeviceArray(1155004.2, dtype=float32), DeviceArray(14262.237, dtype=float32), DeviceArray(1221456.6, dtype=float32), DeviceArray(66452.32, dtype=float32))
# 38
# (DeviceArray(1127198., dtype=float32), DeviceArray(14516.227, dtype=float32), DeviceArray(1239176.2, dtype=float32), DeviceArray(111978.29, dtype=float32))
# 39
# (DeviceArray(1143096.2, dtype=float32), DeviceArray(14379.856, dtype=float32), DeviceArray(1230631., dtype=float32), DeviceArray(87534.805, dtype=float32))
# 40
# (DeviceArray(1135516.9, dtype=float32), DeviceArray(13905.584, dtype=float32), DeviceArray(1138041.4, dtype=float32), DeviceArray(2524.4653, dtype=float32))
# 41
# (DeviceArray(1143735.5, dtype=float32), DeviceArray(13798.676, dtype=float32), DeviceArray(1160373.6, dtype=float32), DeviceArray(16638.154, dtype=float32))
# 42
# (DeviceArray(1125196.4, dtype=float32), DeviceArray(14619.082, dtype=float32), DeviceArray(1255610.9, dtype=float32), DeviceArray(130414.484, dtype=float32))
# 43
# (DeviceArray(1127980.5, dtype=float32), DeviceArray(14911.235, dtype=float32), DeviceArray(1310761.6, dtype=float32), DeviceArray(182781.12, dtype=float32))
# 44
# (DeviceArray(1151636.5, dtype=float32), DeviceArray(14783.584, dtype=float32), DeviceArray(1311536.9, dtype=float32), DeviceArray(159900.42, dtype=float32))
# 45
# (DeviceArray(1136353.8, dtype=float32), DeviceArray(14322.199, dtype=float32), DeviceArray(1213553.9, dtype=float32), DeviceArray(77200.12, dtype=float32))
# 46
# (DeviceArray(1128408.1, dtype=float32), DeviceArray(13746.069, dtype=float32), DeviceArray(1154475.6, dtype=float32), DeviceArray(26067.527, dtype=float32))
# 47
# (DeviceArray(1100373.1, dtype=float32), DeviceArray(14171.93, dtype=float32), DeviceArray(1150638.4, dtype=float32), DeviceArray(50265.25, dtype=float32))
# 48
# (DeviceArray(1094087.2, dtype=float32), DeviceArray(14030.59, dtype=float32), DeviceArray(1119018.2, dtype=float32), DeviceArray(24930.977, dtype=float32))
# 49
# (DeviceArray(1100906.2, dtype=float32), DeviceArray(13750.469, dtype=float32), DeviceArray(1126185.2, dtype=float32), DeviceArray(25278.96, dtype=float32))
# 50
# (DeviceArray(1067950.8, dtype=float32), DeviceArray(14757.218, dtype=float32), DeviceArray(1223125.2, dtype=float32), DeviceArray(155174.44, dtype=float32))
# 51
# (DeviceArray(1058323.5, dtype=float32), DeviceArray(15141.6455, dtype=float32), DeviceArray(1282404.2, dtype=float32), DeviceArray(224080.69, dtype=float32))
# 52
# (DeviceArray(1063806.2, dtype=float32), DeviceArray(15038.961, dtype=float32), DeviceArray(1269481.4, dtype=float32), DeviceArray(205675.12, dtype=float32))
# 53
# (DeviceArray(1078379.5, dtype=float32), DeviceArray(14604.149, dtype=float32), DeviceArray(1206117.4, dtype=float32), DeviceArray(127737.91, dtype=float32))
# 54
# (DeviceArray(1100947.2, dtype=float32), DeviceArray(13967.992, dtype=float32), DeviceArray(1114658., dtype=float32), DeviceArray(13710.741, dtype=float32))
# 55
# (DeviceArray(1107614.4, dtype=float32), DeviceArray(13232.068, dtype=float32), DeviceArray(1225813.4, dtype=float32), DeviceArray(118198.95, dtype=float32))
# 56
# (DeviceArray(1088364.2, dtype=float32), DeviceArray(13467.793, dtype=float32), DeviceArray(1164311., dtype=float32), DeviceArray(75946.81, dtype=float32))
# 57
# (DeviceArray(1048687.5, dtype=float32), DeviceArray(14428.596, dtype=float32), DeviceArray(1144958.5, dtype=float32), DeviceArray(96271.016, dtype=float32))
# 58
# (DeviceArray(1028336.3, dtype=float32), DeviceArray(14732.322, dtype=float32), DeviceArray(1179048.4, dtype=float32), DeviceArray(150712.08, dtype=float32))
# 59
# (DeviceArray(1020544.2, dtype=float32), DeviceArray(14943.131, dtype=float32), DeviceArray(1209042.4, dtype=float32), DeviceArray(188498.19, dtype=float32))
# 60
# (DeviceArray(1032143.56, dtype=float32), DeviceArray(14735.846, dtype=float32), DeviceArray(1183487.2, dtype=float32), DeviceArray(151343.64, dtype=float32))
# 61
# (DeviceArray(1034932., dtype=float32), DeviceArray(14269.969, dtype=float32), DeviceArray(1102770.1, dtype=float32), DeviceArray(67838.13, dtype=float32))
# 62
# (DeviceArray(1055390.6, dtype=float32), DeviceArray(13686.665, dtype=float32), DeviceArray(1092106., dtype=float32), DeviceArray(36715.37, dtype=float32))
# 63
# (DeviceArray(1054797.9, dtype=float32), DeviceArray(14095.508, dtype=float32), DeviceArray(1091365., dtype=float32), DeviceArray(36567.113, dtype=float32))
# 64
# (DeviceArray(1061578.6, dtype=float32), DeviceArray(14332.544, dtype=float32), DeviceArray(1140633., dtype=float32), DeviceArray(79054.34, dtype=float32))
# 65
# (DeviceArray(1061860.5, dtype=float32), DeviceArray(14135.085, dtype=float32), DeviceArray(1105521.6, dtype=float32), DeviceArray(43661.066, dtype=float32))
# 66
# (DeviceArray(1068836.6, dtype=float32), DeviceArray(13624.036, dtype=float32), DeviceArray(1116777.9, dtype=float32), DeviceArray(47941.207, dtype=float32))
# 67
# (DeviceArray(1060578.8, dtype=float32), DeviceArray(14070.566, dtype=float32), DeviceArray(1092675.2, dtype=float32), DeviceArray(32096.521, dtype=float32))
# 68
# (DeviceArray(1036166.1, dtype=float32), DeviceArray(14094.877, dtype=float32), DeviceArray(1072620.1, dtype=float32), DeviceArray(36454.035, dtype=float32))
# 69
# (DeviceArray(1030350., dtype=float32), DeviceArray(13786.955, dtype=float32), DeviceArray(1049089., dtype=float32), DeviceArray(18739.018, dtype=float32))
# 70
# (DeviceArray(1021900.94, dtype=float32), DeviceArray(14347.994, dtype=float32), DeviceArray(1103724.6, dtype=float32), DeviceArray(81823.69, dtype=float32))
# 71
# (DeviceArray(1019756.6, dtype=float32), DeviceArray(14315.391, dtype=float32), DeviceArray(1095736.4, dtype=float32), DeviceArray(75979.72, dtype=float32))
# 72
# (DeviceArray(1011612.3, dtype=float32), DeviceArray(14023.195, dtype=float32), DeviceArray(1035217.9, dtype=float32), DeviceArray(23605.553, dtype=float32))
# 73
# (DeviceArray(1005742.06, dtype=float32), DeviceArray(13556.354, dtype=float32), DeviceArray(1065815., dtype=float32), DeviceArray(60072.89, dtype=float32))
# 74
# (DeviceArray(994048.6, dtype=float32), DeviceArray(14003.066, dtype=float32), DeviceArray(1014046.2, dtype=float32), DeviceArray(19997.574, dtype=float32))
# 75
# (DeviceArray(1001004.6, dtype=float32), DeviceArray(13997.889, dtype=float32), DeviceArray(1020074.1, dtype=float32), DeviceArray(19069.498, dtype=float32))
# 76
# (DeviceArray(1005407.06, dtype=float32), DeviceArray(13581.355, dtype=float32), DeviceArray(1060998.5, dtype=float32), DeviceArray(55591.45, dtype=float32))
# 77
# (DeviceArray(1005200.25, dtype=float32), DeviceArray(13998.76, dtype=float32), DeviceArray(1024425.9, dtype=float32), DeviceArray(19225.635, dtype=float32))
# 78
# (DeviceArray(1007738.4, dtype=float32), DeviceArray(13819.573, dtype=float32), DeviceArray(1020630.8, dtype=float32), DeviceArray(12892.417, dtype=float32))
# 79
# (DeviceArray(984212.1, dtype=float32), DeviceArray(14414.838, dtype=float32), DeviceArray(1078017.1, dtype=float32), DeviceArray(93805.01, dtype=float32))
# 80
# (DeviceArray(982146.94, dtype=float32), DeviceArray(14547.201, dtype=float32), DeviceArray(1099677.2, dtype=float32), DeviceArray(117530.29, dtype=float32))
# 81
# (DeviceArray(984427.75, dtype=float32), DeviceArray(14291.413, dtype=float32), DeviceArray(1056109.6, dtype=float32), DeviceArray(71681.89, dtype=float32))
# 82
# (DeviceArray(973012.6, dtype=float32), DeviceArray(13981.703, dtype=float32), DeviceArray(989180.94, dtype=float32), DeviceArray(16168.34, dtype=float32))
# 83
# (DeviceArray(967834.1, dtype=float32), DeviceArray(13536.756, dtype=float32), DeviceArray(1031419.75, dtype=float32), DeviceArray(63585.645, dtype=float32))
# 84
# (DeviceArray(956257.5, dtype=float32), DeviceArray(14029.084, dtype=float32), DeviceArray(980918.56, dtype=float32), DeviceArray(24661.06, dtype=float32))
# 85
# (DeviceArray(966686.4, dtype=float32), DeviceArray(13946.584, dtype=float32), DeviceArray(976559.8, dtype=float32), DeviceArray(9873.456, dtype=float32))
# 86
# (DeviceArray(972594.25, dtype=float32), DeviceArray(13611.3125, dtype=float32), DeviceArray(1022816.06, dtype=float32), DeviceArray(50221.84, dtype=float32))
# 87
# (DeviceArray(953896.25, dtype=float32), DeviceArray(14187.555, dtype=float32), DeviceArray(1006962.2, dtype=float32), DeviceArray(53065.934, dtype=float32))
# 88
# (DeviceArray(958850.2, dtype=float32), DeviceArray(14150.234, dtype=float32), DeviceArray(1005226.7, dtype=float32), DeviceArray(46376.504, dtype=float32))
# 89
# (DeviceArray(955877., dtype=float32), DeviceArray(14206.254, dtype=float32), DeviceArray(1012294.6, dtype=float32), DeviceArray(56417.65, dtype=float32))
# 90
# (DeviceArray(960906.56, dtype=float32), DeviceArray(13915.584, dtype=float32), DeviceArray(965223.44, dtype=float32), DeviceArray(4316.902, dtype=float32))
# 91
# (DeviceArray(968552.06, dtype=float32), DeviceArray(13337.164, dtype=float32), DeviceArray(1067913.2, dtype=float32), DeviceArray(99361.22, dtype=float32))
# 92
# (DeviceArray(952467.6, dtype=float32), DeviceArray(13730.23, dtype=float32), DeviceArray(981374.2, dtype=float32), DeviceArray(28906.545, dtype=float32))
# 93
# (DeviceArray(940708.25, dtype=float32), DeviceArray(14805.496, dtype=float32), DeviceArray(1104536.2, dtype=float32), DeviceArray(163828.03, dtype=float32))
# 94
# (DeviceArray(937538.75, dtype=float32), DeviceArray(15178.394, dtype=float32), DeviceArray(1168206.2, dtype=float32), DeviceArray(230667.55, dtype=float32))
# 95
# (DeviceArray(932035.94, dtype=float32), DeviceArray(14999.92, dtype=float32), DeviceArray(1130713.2, dtype=float32), DeviceArray(198677.27, dtype=float32))
# 96
# (DeviceArray(935594., dtype=float32), DeviceArray(14412.212, dtype=float32), DeviceArray(1028928.3, dtype=float32), DeviceArray(93334.32, dtype=float32))
# 97
# (DeviceArray(934432.25, dtype=float32), DeviceArray(13566.998, dtype=float32), DeviceArray(992597.2, dtype=float32), DeviceArray(58164.926, dtype=float32))
# 98
# (DeviceArray(925881.6, dtype=float32), DeviceArray(14353.461, dtype=float32), DeviceArray(1008685.2, dtype=float32), DeviceArray(82803.58, dtype=float32))
# 99
# (DeviceArray(930718.6, dtype=float32), DeviceArray(14563.046, dtype=float32), DeviceArray(1051089., dtype=float32), DeviceArray(120370.36, dtype=float32))
# 100
# (DeviceArray(945280.44, dtype=float32), DeviceArray(14465.276, dtype=float32), DeviceArray(1048126.25, dtype=float32), DeviceArray(102845.79, dtype=float32))
# 101
# (DeviceArray(962912.75, dtype=float32), DeviceArray(14111.09, dtype=float32), DeviceArray(1002272.9, dtype=float32), DeviceArray(39360.094, dtype=float32))
# 102
# (DeviceArray(986317.4, dtype=float32), DeviceArray(13443.715, dtype=float32), DeviceArray(1066580., dtype=float32), DeviceArray(80262.664, dtype=float32))
# 103
# (DeviceArray(973443.8, dtype=float32), DeviceArray(13717.186, dtype=float32), DeviceArray(1004688.56, dtype=float32), DeviceArray(31244.764, dtype=float32))
# 104
# (DeviceArray(942511.75, dtype=float32), DeviceArray(14772.742, dtype=float32), DeviceArray(1100468.9, dtype=float32), DeviceArray(157957.1, dtype=float32))
# 105
# (DeviceArray(921735.9, dtype=float32), DeviceArray(15125.955, dtype=float32), DeviceArray(1143004.1, dtype=float32), DeviceArray(221268.28, dtype=float32))
# 106
# (DeviceArray(932370.5, dtype=float32), DeviceArray(14904.361, dtype=float32), DeviceArray(1113919.5, dtype=float32), DeviceArray(181549., dtype=float32))
# 107
# (DeviceArray(943177.75, dtype=float32), DeviceArray(14239.083, dtype=float32), DeviceArray(1005479.8, dtype=float32), DeviceArray(62302.06, dtype=float32))
# 108
# (DeviceArray(961816.4, dtype=float32), DeviceArray(14039.405, dtype=float32), DeviceArray(988327.44, dtype=float32), DeviceArray(26511.086, dtype=float32))
# 109
# (DeviceArray(983632.06, dtype=float32), DeviceArray(13914.168, dtype=float32), DeviceArray(987695.1, dtype=float32), DeviceArray(4063.09, dtype=float32))
# 110
# (DeviceArray(980656.5, dtype=float32), DeviceArray(13662.721, dtype=float32), DeviceArray(1021663.75, dtype=float32), DeviceArray(41007.242, dtype=float32))
# 111
# (DeviceArray(970836.9, dtype=float32), DeviceArray(14417.946, dtype=float32), DeviceArray(1065199., dtype=float32), DeviceArray(94362.17, dtype=float32))
# 112
# (DeviceArray(951296., dtype=float32), DeviceArray(14593.669, dtype=float32), DeviceArray(1077155.4, dtype=float32), DeviceArray(125859.35, dtype=float32))
# 113
# (DeviceArray(964573.75, dtype=float32), DeviceArray(14324.092, dtype=float32), DeviceArray(1042113.1, dtype=float32), DeviceArray(77539.34, dtype=float32))
# 114
# (DeviceArray(978213.94, dtype=float32), DeviceArray(13681.257, dtype=float32), DeviceArray(1015898.7, dtype=float32), DeviceArray(37684.758, dtype=float32))
# 115
# (DeviceArray(961725.7, dtype=float32), DeviceArray(13967.078, dtype=float32), DeviceArray(975272.56, dtype=float32), DeviceArray(13546.901, dtype=float32))
# 116
# (DeviceArray(957497.25, dtype=float32), DeviceArray(13706.635, dtype=float32), DeviceArray(990633.2, dtype=float32), DeviceArray(33135.926, dtype=float32))
# 117
# (DeviceArray(946992.94, dtype=float32), DeviceArray(14306.222, dtype=float32), DeviceArray(1021329.2, dtype=float32), DeviceArray(74336.24, dtype=float32))
# 118
# (DeviceArray(947088.56, dtype=float32), DeviceArray(14415.123, dtype=float32), DeviceArray(1040944.7, dtype=float32), DeviceArray(93856.125, dtype=float32))
# 119
# (DeviceArray(946947.94, dtype=float32), DeviceArray(14279.249, dtype=float32), DeviceArray(1016449.5, dtype=float32), DeviceArray(69501.56, dtype=float32))
# 120
# (DeviceArray(963369.25, dtype=float32), DeviceArray(13772.203, dtype=float32), DeviceArray(984752.44, dtype=float32), DeviceArray(21383.21, dtype=float32))
# 121
# (DeviceArray(964306.1, dtype=float32), DeviceArray(14347.68, dtype=float32), DeviceArray(1046073.44, dtype=float32), DeviceArray(81767.33, dtype=float32))
# 122
# (DeviceArray(959784.94, dtype=float32), DeviceArray(14308.545, dtype=float32), DeviceArray(1034537.6, dtype=float32), DeviceArray(74752.664, dtype=float32))
# 123
# (DeviceArray(958984.4, dtype=float32), DeviceArray(13843.382, dtype=float32), DeviceArray(967609.25, dtype=float32), DeviceArray(8624.877, dtype=float32))
# 124
# (DeviceArray(956316.4, dtype=float32), DeviceArray(14279.817, dtype=float32), DeviceArray(1025919.8, dtype=float32), DeviceArray(69603.44, dtype=float32))
# 125
# (DeviceArray(963658.6, dtype=float32), DeviceArray(14166.177, dtype=float32), DeviceArray(1012892.7, dtype=float32), DeviceArray(49234.074, dtype=float32))
# 126
# (DeviceArray(930160.44, dtype=float32), DeviceArray(13694.718, dtype=float32), DeviceArray(965432.44, dtype=float32), DeviceArray(35271.973, dtype=float32))
# 127
# (DeviceArray(917949.06, dtype=float32), DeviceArray(14111.0625, dtype=float32), DeviceArray(957304.25, dtype=float32), DeviceArray(39355.19, dtype=float32))
# 128
# (DeviceArray(924265.8, dtype=float32), DeviceArray(14152.134, dtype=float32), DeviceArray(970982.75, dtype=float32), DeviceArray(46716.96, dtype=float32))
# 129
# (DeviceArray(938278.9, dtype=float32), DeviceArray(13973.489, dtype=float32), DeviceArray(952974.94, dtype=float32), DeviceArray(14696.057, dtype=float32))
# 130
# (DeviceArray(948932.5, dtype=float32), DeviceArray(13432.531, dtype=float32), DeviceArray(1031199.75, dtype=float32), DeviceArray(82267.25, dtype=float32))
# 131
# (DeviceArray(947132., dtype=float32), DeviceArray(14073.508, dtype=float32), DeviceArray(979755.75, dtype=float32), DeviceArray(32623.75, dtype=float32))
# 132
# (DeviceArray(950326.6, dtype=float32), DeviceArray(14120.74, dtype=float32), DeviceArray(991416.5, dtype=float32), DeviceArray(41089.863, dtype=float32))
# 133
# (DeviceArray(939396.6, dtype=float32), DeviceArray(13768., dtype=float32), DeviceArray(961533.25, dtype=float32), DeviceArray(22136.596, dtype=float32))
# 134
# (DeviceArray(933654.56, dtype=float32), DeviceArray(14346.3, dtype=float32), DeviceArray(1015174.56, dtype=float32), DeviceArray(81519.99, dtype=float32))
# 135
# (DeviceArray(942635.06, dtype=float32), DeviceArray(14302.059, dtype=float32), DeviceArray(1016225.1, dtype=float32), DeviceArray(73590.03, dtype=float32))
# 136
# (DeviceArray(955153.25, dtype=float32), DeviceArray(13797.922, dtype=float32), DeviceArray(971926.56, dtype=float32), DeviceArray(16773.287, dtype=float32))
# 137
# (DeviceArray(920011.9, dtype=float32), DeviceArray(14202.207, dtype=float32), DeviceArray(975704.1, dtype=float32), DeviceArray(55692.273, dtype=float32))
# 138
# (DeviceArray(916662.9, dtype=float32), DeviceArray(14278.869, dtype=float32), DeviceArray(986096.4, dtype=float32), DeviceArray(69433.47, dtype=float32))
# 139
# (DeviceArray(915896.1, dtype=float32), DeviceArray(14022.431, dtype=float32), DeviceArray(939364.6, dtype=float32), DeviceArray(23468.494, dtype=float32))
# 140
# (DeviceArray(918800.94, dtype=float32), DeviceArray(13524.5, dtype=float32), DeviceArray(984583.4, dtype=float32), DeviceArray(65782.43, dtype=float32))
# 141
# (DeviceArray(909100.75, dtype=float32), DeviceArray(14241.037, dtype=float32), DeviceArray(971753.06, dtype=float32), DeviceArray(62652.32, dtype=float32))
# 142
# (DeviceArray(905617.7, dtype=float32), DeviceArray(14333.908, dtype=float32), DeviceArray(984916.56, dtype=float32), DeviceArray(79298.875, dtype=float32))
# 143
# (DeviceArray(908662.5, dtype=float32), DeviceArray(13953.835, dtype=float32), DeviceArray(919835.6, dtype=float32), DeviceArray(11173.148, dtype=float32))
# 144
# (DeviceArray(924057.7, dtype=float32), DeviceArray(13279.109, dtype=float32), DeviceArray(1033824.8, dtype=float32), DeviceArray(109767.15, dtype=float32))
# 145
# (DeviceArray(911624.75, dtype=float32), DeviceArray(13687.992, dtype=float32), DeviceArray(948102.25, dtype=float32), DeviceArray(36477.49, dtype=float32))
# 146
# (DeviceArray(895628.75, dtype=float32), DeviceArray(14804.084, dtype=float32), DeviceArray(1059203.6, dtype=float32), DeviceArray(163574.92, dtype=float32))
# 147
# (DeviceArray(895492.1, dtype=float32), DeviceArray(15192.052, dtype=float32), DeviceArray(1128607.8, dtype=float32), DeviceArray(233115.69, dtype=float32))
# 148
# (DeviceArray(898896.6, dtype=float32), DeviceArray(15128.773, dtype=float32), DeviceArray(1120670.1, dtype=float32), DeviceArray(221773.45, dtype=float32))
# 149
# (DeviceArray(903321.06, dtype=float32), DeviceArray(14824.881, dtype=float32), DeviceArray(1070623.8, dtype=float32), DeviceArray(167302.62, dtype=float32))
# 150
# (DeviceArray(918183.75, dtype=float32), DeviceArray(14220.818, dtype=float32), DeviceArray(977212., dtype=float32), DeviceArray(59028.234, dtype=float32))
# 151
# (DeviceArray(920403.7, dtype=float32), DeviceArray(13516.522, dtype=float32), DeviceArray(987616.06, dtype=float32), DeviceArray(67212.35, dtype=float32))
# 152
# (DeviceArray(918158.9, dtype=float32), DeviceArray(13827.111, dtype=float32), DeviceArray(929700.1, dtype=float32), DeviceArray(11541.263, dtype=float32))
# 153
# (DeviceArray(908293.5, dtype=float32), DeviceArray(14908.916, dtype=float32), DeviceArray(1090658.9, dtype=float32), DeviceArray(182365.39, dtype=float32))
# 154
# (DeviceArray(907062., dtype=float32), DeviceArray(15280.002, dtype=float32), DeviceArray(1155942.2, dtype=float32), DeviceArray(248880.2, dtype=float32))
# 155
# (DeviceArray(891065.25, dtype=float32), DeviceArray(15050.011, dtype=float32), DeviceArray(1098721., dtype=float32), DeviceArray(207655.73, dtype=float32))
# 156
# (DeviceArray(901317.06, dtype=float32), DeviceArray(14504.037, dtype=float32), DeviceArray(1011110.5, dtype=float32), DeviceArray(109793.41, dtype=float32))
# 157
# (DeviceArray(920428.1, dtype=float32), DeviceArray(14107.057, dtype=float32), DeviceArray(959065.3, dtype=float32), DeviceArray(38637.168, dtype=float32))
# 158
# (DeviceArray(936470.8, dtype=float32), DeviceArray(13803.93, dtype=float32), DeviceArray(952167.25, dtype=float32), DeviceArray(15696.426, dtype=float32))
# 159
# (DeviceArray(912193.5, dtype=float32), DeviceArray(14531.543, dtype=float32), DeviceArray(1026917.1, dtype=float32), DeviceArray(114723.66, dtype=float32))
# 160
# (DeviceArray(912100.4, dtype=float32), DeviceArray(14656.344, dtype=float32), DeviceArray(1049193.8, dtype=float32), DeviceArray(137093.4, dtype=float32))
# 161
# (DeviceArray(911776.6, dtype=float32), DeviceArray(14306.699, dtype=float32), DeviceArray(986198.44, dtype=float32), DeviceArray(74421.836, dtype=float32))
# 162
# (DeviceArray(926377.9, dtype=float32), DeviceArray(13700.438, dtype=float32), DeviceArray(960624.44, dtype=float32), DeviceArray(34246.57, dtype=float32))
# 163
# (DeviceArray(925185.4, dtype=float32), DeviceArray(14054.064, dtype=float32), DeviceArray(954324., dtype=float32), DeviceArray(29138.65, dtype=float32))
# 164
# (DeviceArray(922658., dtype=float32), DeviceArray(13881.994, dtype=float32), DeviceArray(924361.9, dtype=float32), DeviceArray(1703.8652, dtype=float32))
# 165
# (DeviceArray(913752.4, dtype=float32), DeviceArray(14554.824, dtype=float32), DeviceArray(1032649.06, dtype=float32), DeviceArray(118896.68, dtype=float32))
# 166
# (DeviceArray(911315.3, dtype=float32), DeviceArray(14581.989, dtype=float32), DeviceArray(1035081.1, dtype=float32), DeviceArray(123765.836, dtype=float32))
# 167
# (DeviceArray(919782.6, dtype=float32), DeviceArray(14414.213, dtype=float32), DeviceArray(1013475.6, dtype=float32), DeviceArray(93692.984, dtype=float32))
# 168
# (DeviceArray(928167.2, dtype=float32), DeviceArray(14142.449, dtype=float32), DeviceArray(973148.25, dtype=float32), DeviceArray(44981.062, dtype=float32))
# 169
# (DeviceArray(933267., dtype=float32), DeviceArray(13500.038, dtype=float32), DeviceArray(1003434.06, dtype=float32), DeviceArray(70167.08, dtype=float32))
# 170
# (DeviceArray(919423., dtype=float32), DeviceArray(13849.879, dtype=float32), DeviceArray(926883.3, dtype=float32), DeviceArray(7460.3184, dtype=float32))
# 171
# (DeviceArray(903880., dtype=float32), DeviceArray(14954.582, dtype=float32), DeviceArray(1094430.8, dtype=float32), DeviceArray(190550.73, dtype=float32))
# 172
# (DeviceArray(892081.3, dtype=float32), DeviceArray(15312.59, dtype=float32), DeviceArray(1146802.8, dtype=float32), DeviceArray(254721.38, dtype=float32))
# 173
# (DeviceArray(884618.7, dtype=float32), DeviceArray(15113.369, dtype=float32), DeviceArray(1103631., dtype=float32), DeviceArray(219012.33, dtype=float32))
# 174
# (DeviceArray(888193.8, dtype=float32), DeviceArray(14481.933, dtype=float32), DeviceArray(994025.1, dtype=float32), DeviceArray(105831.32, dtype=float32))
# 175
# (DeviceArray(901322.56, dtype=float32), DeviceArray(13728.833, dtype=float32), DeviceArray(930479.6, dtype=float32), DeviceArray(29157.031, dtype=float32))
# 176
# (DeviceArray(900559.9, dtype=float32), DeviceArray(14610.078, dtype=float32), DeviceArray(1029360.44, dtype=float32), DeviceArray(128800.586, dtype=float32))
# 177
# (DeviceArray(912908.5, dtype=float32), DeviceArray(14858.715, dtype=float32), DeviceArray(1086275.6, dtype=float32), DeviceArray(173367.16, dtype=float32))
# 178
# (DeviceArray(921853., dtype=float32), DeviceArray(14723.753, dtype=float32), DeviceArray(1071029.1, dtype=float32), DeviceArray(149176.08, dtype=float32))
# 179
# (DeviceArray(925537.4, dtype=float32), DeviceArray(14274.783, dtype=float32), DeviceArray(994238.5, dtype=float32), DeviceArray(68701.09, dtype=float32))
# 180
# (DeviceArray(944120.4, dtype=float32), DeviceArray(13590.156, dtype=float32), DeviceArray(998134.3, dtype=float32), DeviceArray(54013.965, dtype=float32))
# 181
# (DeviceArray(946709.5, dtype=float32), DeviceArray(13922.979, dtype=float32), DeviceArray(952351.8, dtype=float32), DeviceArray(5642.325, dtype=float32))
# 182
# (DeviceArray(930523.06, dtype=float32), DeviceArray(13692.711, dtype=float32), DeviceArray(966154.75, dtype=float32), DeviceArray(35631.684, dtype=float32))
# 183
# (DeviceArray(907678.75, dtype=float32), DeviceArray(14337.037, dtype=float32), DeviceArray(987538.44, dtype=float32), DeviceArray(79859.71, dtype=float32))
# 184
# (DeviceArray(901672.7, dtype=float32), DeviceArray(14363.962, dtype=float32), DeviceArray(986358.5, dtype=float32), DeviceArray(84685.81, dtype=float32))
# 185
# (DeviceArray(903177.06, dtype=float32), DeviceArray(13996.413, dtype=float32), DeviceArray(921982.06, dtype=float32), DeviceArray(18805.008, dtype=float32))
# 186
# (DeviceArray(919298.3, dtype=float32), DeviceArray(13825.938, dtype=float32), DeviceArray(931049.8, dtype=float32), DeviceArray(11751.489, dtype=float32))
# 187
# (DeviceArray(914633.25, dtype=float32), DeviceArray(14529.951, dtype=float32), DeviceArray(1029071.56, dtype=float32), DeviceArray(114438.336, dtype=float32))
# 188
# (DeviceArray(927633., dtype=float32), DeviceArray(14596.987, dtype=float32), DeviceArray(1054087.1, dtype=float32), DeviceArray(126454.14, dtype=float32))
# 189
# (DeviceArray(902985.4, dtype=float32), DeviceArray(14210.289, dtype=float32), DeviceArray(960126.3, dtype=float32), DeviceArray(57140.926, dtype=float32))
# 190
# (DeviceArray(912695., dtype=float32), DeviceArray(13496.092, dtype=float32), DeviceArray(983569.44, dtype=float32), DeviceArray(70874.42, dtype=float32))
# 191
# (DeviceArray(900648.56, dtype=float32), DeviceArray(13803.699, dtype=float32), DeviceArray(916386.3, dtype=float32), DeviceArray(15737.735, dtype=float32))
# 192
# (DeviceArray(885242.75, dtype=float32), DeviceArray(14872.402, dtype=float32), DeviceArray(1061063.2, dtype=float32), DeviceArray(175820.55, dtype=float32))
# 193
# (DeviceArray(884047.44, dtype=float32), DeviceArray(15181.646, dtype=float32), DeviceArray(1115298., dtype=float32), DeviceArray(231250.61, dtype=float32))
# 194
# (DeviceArray(889378.4, dtype=float32), DeviceArray(14870.248, dtype=float32), DeviceArray(1064812.8, dtype=float32), DeviceArray(175434.4, dtype=float32))
# 195
# (DeviceArray(890484.25, dtype=float32), DeviceArray(14517.107, dtype=float32), DeviceArray(1002620.44, dtype=float32), DeviceArray(112136.18, dtype=float32))
# 196
# (DeviceArray(891845.75, dtype=float32), DeviceArray(14106.795, dtype=float32), DeviceArray(930436., dtype=float32), DeviceArray(38590.254, dtype=float32))
# 197
# (DeviceArray(909038.4, dtype=float32), DeviceArray(13503.828, dtype=float32), DeviceArray(978526.1, dtype=float32), DeviceArray(69487.734, dtype=float32))
# 198
# (DeviceArray(905016.7, dtype=float32), DeviceArray(13960.336, dtype=float32), DeviceArray(917355.1, dtype=float32), DeviceArray(12338.407, dtype=float32))
# 199
# (DeviceArray(903634.44, dtype=float32), DeviceArray(13841.209, dtype=float32), DeviceArray(912648.8, dtype=float32), DeviceArray(9014.347, dtype=float32))
# 200
# (DeviceArray(896264., dtype=float32), DeviceArray(14637.732, dtype=float32), DeviceArray(1030021.44, dtype=float32), DeviceArray(133757.45, dtype=float32))
# 201
# (DeviceArray(883969.4, dtype=float32), DeviceArray(14763.736, dtype=float32), DeviceArray(1040312.25, dtype=float32), DeviceArray(156342.86, dtype=float32))
# 202
# (DeviceArray(898481.06, dtype=float32), DeviceArray(14389.791, dtype=float32), DeviceArray(987796.56, dtype=float32), DeviceArray(89315.516, dtype=float32))
# 203
# (DeviceArray(910400.75, dtype=float32), DeviceArray(13979.228, dtype=float32), DeviceArray(926125.4, dtype=float32), DeviceArray(15724.607, dtype=float32))
# 204
# (DeviceArray(935842.9, dtype=float32), DeviceArray(13526.335, dtype=float32), DeviceArray(1001296.4, dtype=float32), DeviceArray(65453.527, dtype=float32))
# 205
# (DeviceArray(930649.5, dtype=float32), DeviceArray(14267.656, dtype=float32), DeviceArray(998073.1, dtype=float32), DeviceArray(67423.63, dtype=float32))
# 206
# (DeviceArray(916109.9, dtype=float32), DeviceArray(14405.948, dtype=float32), DeviceArray(1008321.5, dtype=float32), DeviceArray(92211.59, dtype=float32))
# 207
# (DeviceArray(917191.56, dtype=float32), DeviceArray(14042.137, dtype=float32), DeviceArray(944192.25, dtype=float32), DeviceArray(27000.68, dtype=float32))
# 208
# (DeviceArray(933140.4, dtype=float32), DeviceArray(13321.693, dtype=float32), DeviceArray(1035274.6, dtype=float32), DeviceArray(102134.24, dtype=float32))
# 209
# (DeviceArray(924066.6, dtype=float32), DeviceArray(13604.242, dtype=float32), DeviceArray(975555.75, dtype=float32), DeviceArray(51489.15, dtype=float32))
# 210
# (DeviceArray(895889., dtype=float32), DeviceArray(14673.477, dtype=float32), DeviceArray(1036053.4, dtype=float32), DeviceArray(140164.36, dtype=float32))
# 211
# (DeviceArray(873977.1, dtype=float32), DeviceArray(15002.893, dtype=float32), DeviceArray(1073187.2, dtype=float32), DeviceArray(199210.1, dtype=float32))
# 212
# (DeviceArray(879797.94, dtype=float32), DeviceArray(14790.356, dtype=float32), DeviceArray(1040912.25, dtype=float32), DeviceArray(161114.34, dtype=float32))
# 213
# (DeviceArray(885837.75, dtype=float32), DeviceArray(14465.984, dtype=float32), DeviceArray(988810.44, dtype=float32), DeviceArray(102972.695, dtype=float32))
# 214
# (DeviceArray(898533.9, dtype=float32), DeviceArray(13929.074, dtype=float32), DeviceArray(905268.8, dtype=float32), DeviceArray(6734.9414, dtype=float32))
# 215
# (DeviceArray(915608.1, dtype=float32), DeviceArray(13262.242, dtype=float32), DeviceArray(1028398.6, dtype=float32), DeviceArray(112790.484, dtype=float32))
# 216
# (DeviceArray(899843.75, dtype=float32), DeviceArray(13634.022, dtype=float32), DeviceArray(945995., dtype=float32), DeviceArray(46151.223, dtype=float32))
# 217
# (DeviceArray(885397.7, dtype=float32), DeviceArray(14771.789, dtype=float32), DeviceArray(1043183.94, dtype=float32), DeviceArray(157786.25, dtype=float32))
# 218
# (DeviceArray(870010.4, dtype=float32), DeviceArray(15247.529, dtype=float32), DeviceArray(1113070., dtype=float32), DeviceArray(243059.69, dtype=float32))
# 219
# (DeviceArray(856933.4, dtype=float32), DeviceArray(15106.906, dtype=float32), DeviceArray(1074787.2, dtype=float32), DeviceArray(217853.89, dtype=float32))
# 220
# (DeviceArray(865993.44, dtype=float32), DeviceArray(14495.623, dtype=float32), DeviceArray(974278.7, dtype=float32), DeviceArray(108285.24, dtype=float32))
# 221
# (DeviceArray(885010.75, dtype=float32), DeviceArray(13975.13, dtype=float32), DeviceArray(900000.9, dtype=float32), DeviceArray(14990.128, dtype=float32))
# 222
# (DeviceArray(900117.2, dtype=float32), DeviceArray(13672.044, dtype=float32), DeviceArray(939453.3, dtype=float32), DeviceArray(39336.113, dtype=float32))
# 223
# (DeviceArray(878923.6, dtype=float32), DeviceArray(14395.078, dtype=float32), DeviceArray(969186.8, dtype=float32), DeviceArray(90263.195, dtype=float32))
# 224
# (DeviceArray(880513.9, dtype=float32), DeviceArray(14530.334, dtype=float32), DeviceArray(995020.8, dtype=float32), DeviceArray(114506.95, dtype=float32))
# 225
# (DeviceArray(894977.1, dtype=float32), DeviceArray(14200.148, dtype=float32), DeviceArray(950300.4, dtype=float32), DeviceArray(55323.28, dtype=float32))
# 226
# (DeviceArray(907031., dtype=float32), DeviceArray(13530.873, dtype=float32), DeviceArray(971671.1, dtype=float32), DeviceArray(64640.1, dtype=float32))
# 227
# (DeviceArray(907851.75, dtype=float32), DeviceArray(13891.025, dtype=float32), DeviceArray(907936.8, dtype=float32), DeviceArray(85.07073, dtype=float32))
# 228
# (DeviceArray(897260.44, dtype=float32), DeviceArray(15026.726, dtype=float32), DeviceArray(1100742.5, dtype=float32), DeviceArray(203482.02, dtype=float32))
# 229
# (DeviceArray(887050.3, dtype=float32), DeviceArray(15415.727, dtype=float32), DeviceArray(1160258.2, dtype=float32), DeviceArray(273207.97, dtype=float32))
# 230
# (DeviceArray(886329., dtype=float32), DeviceArray(15160.538, dtype=float32), DeviceArray(1113796., dtype=float32), DeviceArray(227467.06, dtype=float32))
# 231
# (DeviceArray(886051.75, dtype=float32), DeviceArray(14409.942, dtype=float32), DeviceArray(978979.25, dtype=float32), DeviceArray(92927.52, dtype=float32))
# 232
# (DeviceArray(913565.5, dtype=float32), DeviceArray(14187.77, dtype=float32), DeviceArray(966669.94, dtype=float32), DeviceArray(53104.44, dtype=float32))
# 233
# (DeviceArray(936829.4, dtype=float32), DeviceArray(13893.104, dtype=float32), DeviceArray(937116.8, dtype=float32), DeviceArray(287.42004, dtype=float32))
# 234
# (DeviceArray(960921.8, dtype=float32), DeviceArray(13413.33, dtype=float32), DeviceArray(1046630.75, dtype=float32), DeviceArray(85708.94, dtype=float32))
# 235
# (DeviceArray(938759.25, dtype=float32), DeviceArray(14126.048, dtype=float32), DeviceArray(980800.5, dtype=float32), DeviceArray(42041.223, dtype=float32))
# 236
# (DeviceArray(942798.9, dtype=float32), DeviceArray(14316.824, dtype=float32), DeviceArray(1019035.56, dtype=float32), DeviceArray(76236.68, dtype=float32))
# 237
# (DeviceArray(940324.6, dtype=float32), DeviceArray(14070.93, dtype=float32), DeviceArray(972486.25, dtype=float32), DeviceArray(32161.639, dtype=float32))
# 238
# (DeviceArray(953962., dtype=float32), DeviceArray(13450.172, dtype=float32), DeviceArray(1033067.25, dtype=float32), DeviceArray(79105.28, dtype=float32))
# 239
# (DeviceArray(944172.9, dtype=float32), DeviceArray(13964.056, dtype=float32), DeviceArray(957178., dtype=float32), DeviceArray(13005.145, dtype=float32))
# 240
# (DeviceArray(937224.9, dtype=float32), DeviceArray(13902., dtype=float32), DeviceArray(939106.94, dtype=float32), DeviceArray(1882.0587, dtype=float32))
# 241
# (DeviceArray(952100.7, dtype=float32), DeviceArray(13758.547, dtype=float32), DeviceArray(975931.7, dtype=float32), DeviceArray(23831.008, dtype=float32))
# 242
# (DeviceArray(935886.9, dtype=float32), DeviceArray(14961.639, dtype=float32), DeviceArray(1127702.5, dtype=float32), DeviceArray(191815.6, dtype=float32))
# 243
# (DeviceArray(932091.9, dtype=float32), DeviceArray(15429.055, dtype=float32), DeviceArray(1207688.9, dtype=float32), DeviceArray(275596.97, dtype=float32))
# 244
# (DeviceArray(940366.9, dtype=float32), DeviceArray(15321.201, dtype=float32), DeviceArray(1196631.8, dtype=float32), DeviceArray(256264.9, dtype=float32))
# 245
# (DeviceArray(930384.4, dtype=float32), DeviceArray(14828.736, dtype=float32), DeviceArray(1098378., dtype=float32), DeviceArray(167993.69, dtype=float32))
# 246
# (DeviceArray(956885.2, dtype=float32), DeviceArray(14100.375, dtype=float32), DeviceArray(994324.7, dtype=float32), DeviceArray(37439.523, dtype=float32))
# 247
# (DeviceArray(942975.1, dtype=float32), DeviceArray(13333.844, dtype=float32), DeviceArray(1042931.5, dtype=float32), DeviceArray(99956.36, dtype=float32))
# 248
# (DeviceArray(948992.75, dtype=float32), DeviceArray(13706.795, dtype=float32), DeviceArray(982100., dtype=float32), DeviceArray(33107.22, dtype=float32))
# 249
# (DeviceArray(916751.9, dtype=float32), DeviceArray(14893.619, dtype=float32), DeviceArray(1096375.4, dtype=float32), DeviceArray(179623.53, dtype=float32))
# 250
# (DeviceArray(914597., dtype=float32), DeviceArray(15360.856, dtype=float32), DeviceArray(1177969.9, dtype=float32), DeviceArray(263372.88, dtype=float32))
# 251
# (DeviceArray(918194., dtype=float32), DeviceArray(15725.656, dtype=float32), DeviceArray(1246954.9, dtype=float32), DeviceArray(328760.9, dtype=float32))
# 252
# (DeviceArray(914816.9, dtype=float32), DeviceArray(15641.355, dtype=float32), DeviceArray(1228467.4, dtype=float32), DeviceArray(313650.53, dtype=float32))
# 253
# (DeviceArray(934063.6, dtype=float32), DeviceArray(15074.477, dtype=float32), DeviceArray(1146104.8, dtype=float32), DeviceArray(212041.08, dtype=float32))
# 254
# (DeviceArray(963818.1, dtype=float32), DeviceArray(14261.578, dtype=float32), DeviceArray(1030152.3, dtype=float32), DeviceArray(66334.164, dtype=float32))
# 255
# (DeviceArray(954775.5, dtype=float32), DeviceArray(14009.865, dtype=float32), DeviceArray(975991.75, dtype=float32), DeviceArray(21216.22, dtype=float32))
# 256
# (DeviceArray(970101.9, dtype=float32), DeviceArray(13715.602, dtype=float32), DeviceArray(1001630.56, dtype=float32), DeviceArray(31528.684, dtype=float32))
# 257
# (DeviceArray(972925.6, dtype=float32), DeviceArray(14571.324, dtype=float32), DeviceArray(1094779.9, dtype=float32), DeviceArray(121854.195, dtype=float32))
# 258
# (DeviceArray(976365.9, dtype=float32), DeviceArray(14858.616, dtype=float32), DeviceArray(1149715.4, dtype=float32), DeviceArray(173349.47, dtype=float32))
# 259
# (DeviceArray(976172.2, dtype=float32), DeviceArray(14664.98, dtype=float32), DeviceArray(1114813.6, dtype=float32), DeviceArray(138641.48, dtype=float32))
# 260
# (DeviceArray(961483.5, dtype=float32), DeviceArray(14088.971, dtype=float32), DeviceArray(996878.9, dtype=float32), DeviceArray(35395.375, dtype=float32))
# 261
# (DeviceArray(988259.3, dtype=float32), DeviceArray(13281.609, dtype=float32), DeviceArray(1097578.4, dtype=float32), DeviceArray(109319.04, dtype=float32))
# 262
# (DeviceArray(977277.4, dtype=float32), DeviceArray(13612.6875, dtype=float32), DeviceArray(1027252.75, dtype=float32), DeviceArray(49975.38, dtype=float32))
# 263
# (DeviceArray(959053.2, dtype=float32), DeviceArray(14742.66, dtype=float32), DeviceArray(1111618.2, dtype=float32), DeviceArray(152565.08, dtype=float32))
# 264
# (DeviceArray(949731.3, dtype=float32), DeviceArray(15183.936, dtype=float32), DeviceArray(1181392.2, dtype=float32), DeviceArray(231660.9, dtype=float32))
# 265
# (DeviceArray(940433., dtype=float32), DeviceArray(15305.557, dtype=float32), DeviceArray(1193893.8, dtype=float32), DeviceArray(253460.72, dtype=float32))
# 266
# (DeviceArray(926956.9, dtype=float32), DeviceArray(15094.278, dtype=float32), DeviceArray(1142547.2, dtype=float32), DeviceArray(215590.42, dtype=float32))
# 267
# (DeviceArray(945415.75, dtype=float32), DeviceArray(14477.246, dtype=float32), DeviceArray(1050407., dtype=float32), DeviceArray(104991.29, dtype=float32))
# 268
# (DeviceArray(969993.8, dtype=float32), DeviceArray(13986.795, dtype=float32), DeviceArray(987074.8, dtype=float32), DeviceArray(17081.014, dtype=float32))
# 269
# (DeviceArray(982398.9, dtype=float32), DeviceArray(13377.18, dtype=float32), DeviceArray(1074587.5, dtype=float32), DeviceArray(92188.664, dtype=float32))
# 270
# (DeviceArray(980881.8, dtype=float32), DeviceArray(13954.273, dtype=float32), DeviceArray(992133.56, dtype=float32), DeviceArray(11251.742, dtype=float32))
# 271
# (DeviceArray(958121.1, dtype=float32), DeviceArray(14005.715, dtype=float32), DeviceArray(978593.44, dtype=float32), DeviceArray(20472.29, dtype=float32))
# 272
# (DeviceArray(963633.9, dtype=float32), DeviceArray(13605.796, dtype=float32), DeviceArray(1014844.5, dtype=float32), DeviceArray(51210.656, dtype=float32))
# 273
# (DeviceArray(959087.4, dtype=float32), DeviceArray(14187.906, dtype=float32), DeviceArray(1012216.3, dtype=float32), DeviceArray(53128.95, dtype=float32))
# 274
# (DeviceArray(962282.9, dtype=float32), DeviceArray(14170.398, dtype=float32), DeviceArray(1012273.6, dtype=float32), DeviceArray(49990.78, dtype=float32))
# 275
# (DeviceArray(946645.1, dtype=float32), DeviceArray(14202.448, dtype=float32), DeviceArray(1002380.6, dtype=float32), DeviceArray(55735.508, dtype=float32))
# 276
# (DeviceArray(955355.5, dtype=float32), DeviceArray(13860.181, dtype=float32), DeviceArray(960969.3, dtype=float32), DeviceArray(5613.793, dtype=float32))
# 277
# (DeviceArray(927435.75, dtype=float32), DeviceArray(14453.783, dtype=float32), DeviceArray(1028221.44, dtype=float32), DeviceArray(100785.71, dtype=float32))
# 278
# (DeviceArray(931193.9, dtype=float32), DeviceArray(14496.637, dtype=float32), DeviceArray(1039660.8, dtype=float32), DeviceArray(108466.94, dtype=float32))
# 279
# (DeviceArray(941806.94, dtype=float32), DeviceArray(14108.927, dtype=float32), DeviceArray(980779.3, dtype=float32), DeviceArray(38972.37, dtype=float32))
# 280
# (DeviceArray(959845.75, dtype=float32), DeviceArray(13375.724, dtype=float32), DeviceArray(1052295.4, dtype=float32), DeviceArray(92449.66, dtype=float32))
# 281
# (DeviceArray(945892.25, dtype=float32), DeviceArray(13699.934, dtype=float32), DeviceArray(980229.3, dtype=float32), DeviceArray(34337.066, dtype=float32))
# 282
# (DeviceArray(916480.1, dtype=float32), DeviceArray(14794.612, dtype=float32), DeviceArray(1078357.2, dtype=float32), DeviceArray(161877.17, dtype=float32))
# 283
# (DeviceArray(898962.9, dtype=float32), DeviceArray(15131.328, dtype=float32), DeviceArray(1121194.2, dtype=float32), DeviceArray(222231.36, dtype=float32))
# 284
# (DeviceArray(898338.1, dtype=float32), DeviceArray(14848.779, dtype=float32), DeviceArray(1069924.4, dtype=float32), DeviceArray(171586.27, dtype=float32))
# 285
# (DeviceArray(920822.25, dtype=float32), DeviceArray(14701.54, dtype=float32), DeviceArray(1066016.8, dtype=float32), DeviceArray(145194.56, dtype=float32))
# 286
# (DeviceArray(913695., dtype=float32), DeviceArray(14494.379, dtype=float32), DeviceArray(1021757.25, dtype=float32), DeviceArray(108062.234, dtype=float32))
# 287
# (DeviceArray(942466.1, dtype=float32), DeviceArray(14002.963, dtype=float32), DeviceArray(962445.1, dtype=float32), DeviceArray(19979.02, dtype=float32))
# 288
# (DeviceArray(940645.6, dtype=float32), DeviceArray(13337.773, dtype=float32), DeviceArray(1039897.6, dtype=float32), DeviceArray(99251.99, dtype=float32))
# 289
# (DeviceArray(934425.4, dtype=float32), DeviceArray(13794.527, dtype=float32), DeviceArray(951807.1, dtype=float32), DeviceArray(17381.736, dtype=float32))
# 290
# (DeviceArray(924759.1, dtype=float32), DeviceArray(15036.199, dtype=float32), DeviceArray(1129939.2, dtype=float32), DeviceArray(205180.11, dtype=float32))
# 291
# (DeviceArray(924102.25, dtype=float32), DeviceArray(15518.983, dtype=float32), DeviceArray(1215818.4, dtype=float32), DeviceArray(291716.12, dtype=float32))
# 292
# (DeviceArray(898873.1, dtype=float32), DeviceArray(15352.348, dtype=float32), DeviceArray(1160720.9, dtype=float32), DeviceArray(261847.72, dtype=float32))
# 293
# (DeviceArray(909155.75, dtype=float32), DeviceArray(14789.604, dtype=float32), DeviceArray(1070135.1, dtype=float32), DeviceArray(160979.38, dtype=float32))
# 294
# (DeviceArray(924288.6, dtype=float32), DeviceArray(14364.1045, dtype=float32), DeviceArray(1009000., dtype=float32), DeviceArray(84711.37, dtype=float32))
# 295
# (DeviceArray(927858.5, dtype=float32), DeviceArray(13705.715, dtype=float32), DeviceArray(961159.3, dtype=float32), DeviceArray(33300.816, dtype=float32))
# 296
# (DeviceArray(915540.6, dtype=float32), DeviceArray(14276.924, dtype=float32), DeviceArray(984625.44, dtype=float32), DeviceArray(69084.79, dtype=float32))
# 297
# (DeviceArray(925716.56, dtype=float32), DeviceArray(14286.761, dtype=float32), DeviceArray(996564.56, dtype=float32), DeviceArray(70847.99, dtype=float32))
# 298
# (DeviceArray(930189.5, dtype=float32), DeviceArray(13860.434, dtype=float32), DeviceArray(935757.94, dtype=float32), DeviceArray(5568.457, dtype=float32))
# 299
# (DeviceArray(921513.1, dtype=float32), DeviceArray(14768.299, dtype=float32), DeviceArray(1078673.8, dtype=float32), DeviceArray(157160.66, dtype=float32))
# 300
# ...
# 901
# (DeviceArray(169884.56, dtype=float32), DeviceArray(14198.742, dtype=float32), DeviceArray(172891.6, dtype=float32), DeviceArray(3007.0237, dtype=float32))
# 902
# (DeviceArray(170737.12, dtype=float32), DeviceArray(13648.535, dtype=float32), DeviceArray(173115.06, dtype=float32), DeviceArray(2377.9321, dtype=float32))
# 903
# (DeviceArray(170729.84, dtype=float32), DeviceArray(14288.279, dtype=float32), DeviceArray(174613.19, dtype=float32), DeviceArray(3883.3364, dtype=float32))
# 904
# (DeviceArray(170048.53, dtype=float32), DeviceArray(14202.719, dtype=float32), DeviceArray(173094.47, dtype=float32), DeviceArray(3045.9429, dtype=float32))
# 905
# (DeviceArray(170208.73, dtype=float32), DeviceArray(13567.16, dtype=float32), DeviceArray(173383.1, dtype=float32), DeviceArray(3174.361, dtype=float32))
# 906
# (DeviceArray(170205.55, dtype=float32), DeviceArray(14029.812, dtype=float32), DeviceArray(171559.22, dtype=float32), DeviceArray(1353.6749, dtype=float32))
# 907
# (DeviceArray(170493.9, dtype=float32), DeviceArray(13795.838, dtype=float32), DeviceArray(171430.17, dtype=float32), DeviceArray(936.2589, dtype=float32))
# 908
# (DeviceArray(169636.73, dtype=float32), DeviceArray(14588.71, dtype=float32), DeviceArray(176460.42, dtype=float32), DeviceArray(6823.695, dtype=float32))
# 909
# (DeviceArray(169675.53, dtype=float32), DeviceArray(14567.848, dtype=float32), DeviceArray(176295.05, dtype=float32), DeviceArray(6619.512, dtype=float32))
# 910
# (DeviceArray(170146.53, dtype=float32), DeviceArray(14057.406, dtype=float32), DeviceArray(171770.28, dtype=float32), DeviceArray(1623.7484, dtype=float32))
# 911
# (DeviceArray(170290.9, dtype=float32), DeviceArray(13076.995, dtype=float32), DeviceArray(178262.58, dtype=float32), DeviceArray(7971.6772, dtype=float32))
# 912
# (DeviceArray(169945.14, dtype=float32), DeviceArray(13236.526, dtype=float32), DeviceArray(176355.47, dtype=float32), DeviceArray(6410.322, dtype=float32))
# 913
# (DeviceArray(169272.97, dtype=float32), DeviceArray(14302.559, dtype=float32), DeviceArray(173296.06, dtype=float32), DeviceArray(4023.0898, dtype=float32))
# 914
# (DeviceArray(169022.34, dtype=float32), DeviceArray(14483.279, dtype=float32), DeviceArray(174814.17, dtype=float32), DeviceArray(5791.8296, dtype=float32))
# 915
# (DeviceArray(169399.75, dtype=float32), DeviceArray(14251.778, dtype=float32), DeviceArray(172925.84, dtype=float32), DeviceArray(3526.096, dtype=float32))
# 916
# (DeviceArray(170246.22, dtype=float32), DeviceArray(13751.393, dtype=float32), DeviceArray(171617.47, dtype=float32), DeviceArray(1371.2516, dtype=float32))
# 917
# (DeviceArray(169168.05, dtype=float32), DeviceArray(14360.414, dtype=float32), DeviceArray(173757.38, dtype=float32), DeviceArray(4589.3296, dtype=float32))
# 918
# (DeviceArray(169399.94, dtype=float32), DeviceArray(14227.649, dtype=float32), DeviceArray(172689.88, dtype=float32), DeviceArray(3289.9429, dtype=float32))
# 919
# (DeviceArray(170010.44, dtype=float32), DeviceArray(13530.068, dtype=float32), DeviceArray(173547.83, dtype=float32), DeviceArray(3537.3838, dtype=float32))
# 920
# (DeviceArray(170095.28, dtype=float32), DeviceArray(13960.281, dtype=float32), DeviceArray(170768.45, dtype=float32), DeviceArray(673.17206, dtype=float32))
# 921
# (DeviceArray(170451.1, dtype=float32), DeviceArray(13681.904, dtype=float32), DeviceArray(172502.44, dtype=float32), DeviceArray(2051.3435, dtype=float32))
# 922
# (DeviceArray(169846.62, dtype=float32), DeviceArray(14403.166, dtype=float32), DeviceArray(174854.38, dtype=float32), DeviceArray(5007.7495, dtype=float32))
# 923
# (DeviceArray(170190.05, dtype=float32), DeviceArray(14325.866, dtype=float32), DeviceArray(174441.25, dtype=float32), DeviceArray(4251.205, dtype=float32))
# 924
# (DeviceArray(171184.56, dtype=float32), DeviceArray(13613.098, dtype=float32), DeviceArray(173909.33, dtype=float32), DeviceArray(2724.764, dtype=float32))
# 925
# (DeviceArray(169383.34, dtype=float32), DeviceArray(14009.635, dtype=float32), DeviceArray(170539.55, dtype=float32), DeviceArray(1156.202, dtype=float32))
# 926
# (DeviceArray(169098.42, dtype=float32), DeviceArray(13983.515, dtype=float32), DeviceArray(169998.98, dtype=float32), DeviceArray(900.56067, dtype=float32))
# 927
# (DeviceArray(169355.16, dtype=float32), DeviceArray(13526.926, dtype=float32), DeviceArray(172923.3, dtype=float32), DeviceArray(3568.1406, dtype=float32))
# 928
# (DeviceArray(168644.66, dtype=float32), DeviceArray(14108.458, dtype=float32), DeviceArray(170768.06, dtype=float32), DeviceArray(2123.3994, dtype=float32))
# 929
# (DeviceArray(168720.7, dtype=float32), DeviceArray(13913.279, dtype=float32), DeviceArray(168933.86, dtype=float32), DeviceArray(213.15714, dtype=float32))
# 930
# (DeviceArray(169413.9, dtype=float32), DeviceArray(13100.803, dtype=float32), DeviceArray(177152.58, dtype=float32), DeviceArray(7738.6685, dtype=float32))
# 931
# (DeviceArray(168970.73, dtype=float32), DeviceArray(13407.641, dtype=float32), DeviceArray(173706.34, dtype=float32), DeviceArray(4735.6016, dtype=float32))
# 932
# (DeviceArray(167712.69, dtype=float32), DeviceArray(14599.916, dtype=float32), DeviceArray(174646.06, dtype=float32), DeviceArray(6933.37, dtype=float32))
# 933
# (DeviceArray(167732.44, dtype=float32), DeviceArray(14908.539, dtype=float32), DeviceArray(177686.34, dtype=float32), DeviceArray(9953.908, dtype=float32))
# 934
# (DeviceArray(167989.83, dtype=float32), DeviceArray(14462.93, dtype=float32), DeviceArray(173582.5, dtype=float32), DeviceArray(5592.665, dtype=float32))
# 935
# (DeviceArray(168134.88, dtype=float32), DeviceArray(13526.591, dtype=float32), DeviceArray(171706.3, dtype=float32), DeviceArray(3571.419, dtype=float32))
# 936
# (DeviceArray(167657.81, dtype=float32), DeviceArray(14310.901, dtype=float32), DeviceArray(171762.55, dtype=float32), DeviceArray(4104.7417, dtype=float32))
# 937
# (DeviceArray(168237.16, dtype=float32), DeviceArray(14314.992, dtype=float32), DeviceArray(172381.94, dtype=float32), DeviceArray(4144.7793, dtype=float32))
# 938
# (DeviceArray(168711.23, dtype=float32), DeviceArray(13843.6045, dtype=float32), DeviceArray(169180., dtype=float32), DeviceArray(468.76025, dtype=float32))
# 939
# (DeviceArray(168270.56, dtype=float32), DeviceArray(14461.373, dtype=float32), DeviceArray(173848., dtype=float32), DeviceArray(5577.43, dtype=float32))
# 940
# (DeviceArray(168758.47, dtype=float32), DeviceArray(14355.816, dtype=float32), DeviceArray(173302.8, dtype=float32), DeviceArray(4544.332, dtype=float32))
# 941
# (DeviceArray(169406.72, dtype=float32), DeviceArray(13668.675, dtype=float32), DeviceArray(171587.55, dtype=float32), DeviceArray(2180.8225, dtype=float32))
# 942
# (DeviceArray(169174.67, dtype=float32), DeviceArray(14138.166, dtype=float32), DeviceArray(171588.83, dtype=float32), DeviceArray(2414.156, dtype=float32))
# 943
# (DeviceArray(169260., dtype=float32), DeviceArray(13865.088, dtype=float32), DeviceArray(169518.5, dtype=float32), DeviceArray(258.49915, dtype=float32))
# 944
# (DeviceArray(168642.86, dtype=float32), DeviceArray(14606.547, dtype=float32), DeviceArray(175641.12, dtype=float32), DeviceArray(6998.267, dtype=float32))
# 945
# (DeviceArray(168342.75, dtype=float32), DeviceArray(14506.957, dtype=float32), DeviceArray(174366.31, dtype=float32), DeviceArray(6023.567, dtype=float32))
# 946
# (DeviceArray(168715.67, dtype=float32), DeviceArray(13804.282, dtype=float32), DeviceArray(169569.28, dtype=float32), DeviceArray(853.613, dtype=float32))
# 947
# (DeviceArray(168228.12, dtype=float32), DeviceArray(14170.37, dtype=float32), DeviceArray(170957.47, dtype=float32), DeviceArray(2729.3423, dtype=float32))
# 948
# (DeviceArray(168618.73, dtype=float32), DeviceArray(13769.104, dtype=float32), DeviceArray(169816.64, dtype=float32), DeviceArray(1197.9121, dtype=float32))
# 949
# (DeviceArray(167832.62, dtype=float32), DeviceArray(14438.383, dtype=float32), DeviceArray(173185.05, dtype=float32), DeviceArray(5352.4214, dtype=float32))
# 950
# (DeviceArray(167611.02, dtype=float32), DeviceArray(14493.304, dtype=float32), DeviceArray(173500.95, dtype=float32), DeviceArray(5889.94, dtype=float32))
# 951
# (DeviceArray(167338.38, dtype=float32), DeviceArray(13928.926, dtype=float32), DeviceArray(167704.67, dtype=float32), DeviceArray(366.29153, dtype=float32))
# 952
# (DeviceArray(167934.97, dtype=float32), DeviceArray(13315.086, dtype=float32), DeviceArray(173576.42, dtype=float32), DeviceArray(5641.4478, dtype=float32))
# 953
# (DeviceArray(167905.1, dtype=float32), DeviceArray(14029.496, dtype=float32), DeviceArray(169255.69, dtype=float32), DeviceArray(1350.5878, dtype=float32))
# 954
# (DeviceArray(168776.47, dtype=float32), DeviceArray(14006.501, dtype=float32), DeviceArray(169902., dtype=float32), DeviceArray(1125.5312, dtype=float32))
# 955
# (DeviceArray(170214.77, dtype=float32), DeviceArray(13438.053, dtype=float32), DeviceArray(174652.72, dtype=float32), DeviceArray(4437.954, dtype=float32))
# 956
# (DeviceArray(168917.69, dtype=float32), DeviceArray(14063.67, dtype=float32), DeviceArray(170602.73, dtype=float32), DeviceArray(1685.0519, dtype=float32))
# 957
# (DeviceArray(168709.5, dtype=float32), DeviceArray(13941.641, dtype=float32), DeviceArray(169200.23, dtype=float32), DeviceArray(490.73355, dtype=float32))
# 958
# (DeviceArray(169865.28, dtype=float32), DeviceArray(13319.85, dtype=float32), DeviceArray(175460.11, dtype=float32), DeviceArray(5594.825, dtype=float32))
# 959
# (DeviceArray(169332.84, dtype=float32), DeviceArray(13981.951, dtype=float32), DeviceArray(170218.11, dtype=float32), DeviceArray(885.2587, dtype=float32))
# 960
# (DeviceArray(169585.02, dtype=float32), DeviceArray(13857.271, dtype=float32), DeviceArray(169920.02, dtype=float32), DeviceArray(334.99942, dtype=float32))
# 961
# (DeviceArray(168824.16, dtype=float32), DeviceArray(14745.949, dtype=float32), DeviceArray(177186.78, dtype=float32), DeviceArray(8362.618, dtype=float32))
# 962
# (DeviceArray(169028.52, dtype=float32), DeviceArray(14784.912, dtype=float32), DeviceArray(177772.47, dtype=float32), DeviceArray(8743.953, dtype=float32))
# 963
# (DeviceArray(169654.19, dtype=float32), DeviceArray(14209.21, dtype=float32), DeviceArray(172763.66, dtype=float32), DeviceArray(3109.4734, dtype=float32))
# 964
# (DeviceArray(170089.6, dtype=float32), DeviceArray(13677.761, dtype=float32), DeviceArray(172181.48, dtype=float32), DeviceArray(2091.897, dtype=float32))
# 965
# (DeviceArray(170046.94, dtype=float32), DeviceArray(14255.154, dtype=float32), DeviceArray(173606.08, dtype=float32), DeviceArray(3559.1372, dtype=float32))
# 966
# (DeviceArray(170446.88, dtype=float32), DeviceArray(14056.945, dtype=float32), DeviceArray(172066.11, dtype=float32), DeviceArray(1619.2372, dtype=float32))
# 967
# (DeviceArray(170577.58, dtype=float32), DeviceArray(13323.904, dtype=float32), DeviceArray(176132.72, dtype=float32), DeviceArray(5555.141, dtype=float32))
# 968
# (DeviceArray(170229.94, dtype=float32), DeviceArray(13745.957, dtype=float32), DeviceArray(171654.39, dtype=float32), DeviceArray(1424.4501, dtype=float32))
# 969
# (DeviceArray(169226.31, dtype=float32), DeviceArray(15079.264, dtype=float32), DeviceArray(180851.12, dtype=float32), DeviceArray(11624.814, dtype=float32))
# 970
# (DeviceArray(168772.75, dtype=float32), DeviceArray(15500.5, dtype=float32), DeviceArray(184520.27, dtype=float32), DeviceArray(15747.516, dtype=float32))
# 971
# (DeviceArray(168949.44, dtype=float32), DeviceArray(15143.598, dtype=float32), DeviceArray(181203.9, dtype=float32), DeviceArray(12254.461, dtype=float32))
# 972
# (DeviceArray(170276.75, dtype=float32), DeviceArray(14206.224, dtype=float32), DeviceArray(173357., dtype=float32), DeviceArray(3080.2456, dtype=float32))
# 973
# (DeviceArray(170475.94, dtype=float32), DeviceArray(13091.448, dtype=float32), DeviceArray(178306.16, dtype=float32), DeviceArray(7830.222, dtype=float32))
# 974
# (DeviceArray(170472.72, dtype=float32), DeviceArray(13991.744, dtype=float32), DeviceArray(171453.83, dtype=float32), DeviceArray(981.1039, dtype=float32))
# 975
# (DeviceArray(170808.25, dtype=float32), DeviceArray(14258.879, dtype=float32), DeviceArray(174403.84, dtype=float32), DeviceArray(3595.5906, dtype=float32))
# 976
# (DeviceArray(170025.66, dtype=float32), DeviceArray(14013.785, dtype=float32), DeviceArray(171222.48, dtype=float32), DeviceArray(1196.8225, dtype=float32))
# 977
# (DeviceArray(170883.88, dtype=float32), DeviceArray(13357.912, dtype=float32), DeviceArray(176106.17, dtype=float32), DeviceArray(5222.302, dtype=float32))
# 978
# (DeviceArray(171061.05, dtype=float32), DeviceArray(13938.367, dtype=float32), DeviceArray(171519.75, dtype=float32), DeviceArray(458.69595, dtype=float32))
# 979
# (DeviceArray(171099.06, dtype=float32), DeviceArray(13789.301, dtype=float32), DeviceArray(172099.3, dtype=float32), DeviceArray(1000.2385, dtype=float32))
# 980
# (DeviceArray(170482.88, dtype=float32), DeviceArray(14653.32, dtype=float32), DeviceArray(177938.92, dtype=float32), DeviceArray(7456.0454, dtype=float32))
# 981
# (DeviceArray(169590.83, dtype=float32), DeviceArray(14719.106, dtype=float32), DeviceArray(177690.73, dtype=float32), DeviceArray(8099.904, dtype=float32))
# 982
# (DeviceArray(170833.4, dtype=float32), DeviceArray(14141.709, dtype=float32), DeviceArray(173282.23, dtype=float32), DeviceArray(2448.8315, dtype=float32))
# 983
# (DeviceArray(171910.12, dtype=float32), DeviceArray(13192.967, dtype=float32), DeviceArray(178746.77, dtype=float32), DeviceArray(6836.6455, dtype=float32))
# 984
# (DeviceArray(171665.81, dtype=float32), DeviceArray(13492.648, dtype=float32), DeviceArray(175569.44, dtype=float32), DeviceArray(3903.618, dtype=float32))
# 985
# (DeviceArray(170145.94, dtype=float32), DeviceArray(14704.094, dtype=float32), DeviceArray(178098.9, dtype=float32), DeviceArray(7952.9727, dtype=float32))
# 986
# (DeviceArray(169662.6, dtype=float32), DeviceArray(15009.252, dtype=float32), DeviceArray(180602.19, dtype=float32), DeviceArray(10939.6, dtype=float32))
# 987
# (DeviceArray(169191.81, dtype=float32), DeviceArray(14744.937, dtype=float32), DeviceArray(177544.52, dtype=float32), DeviceArray(8352.707, dtype=float32))
# 988
# (DeviceArray(169689.47, dtype=float32), DeviceArray(14287.646, dtype=float32), DeviceArray(173566.61, dtype=float32), DeviceArray(3877.143, dtype=float32))
# 989
# (DeviceArray(170506.19, dtype=float32), DeviceArray(13391.242, dtype=float32), DeviceArray(175402.28, dtype=float32), DeviceArray(4896.0957, dtype=float32))
# 990
# (DeviceArray(169699.47, dtype=float32), DeviceArray(13790.46, dtype=float32), DeviceArray(170688.36, dtype=float32), DeviceArray(988.8935, dtype=float32))
# 991
# (DeviceArray(169031.73, dtype=float32), DeviceArray(15097.771, dtype=float32), DeviceArray(180837.69, dtype=float32), DeviceArray(11805.953, dtype=float32))
# 992
# (DeviceArray(168936.31, dtype=float32), DeviceArray(15517.343, dtype=float32), DeviceArray(184848.67, dtype=float32), DeviceArray(15912.358, dtype=float32))
# 993
# (DeviceArray(168477.81, dtype=float32), DeviceArray(15213.275, dtype=float32), DeviceArray(181414.22, dtype=float32), DeviceArray(12936.407, dtype=float32))
# 994
# (DeviceArray(168879.2, dtype=float32), DeviceArray(14350.59, dtype=float32), DeviceArray(173372.38, dtype=float32), DeviceArray(4493.1787, dtype=float32))
# 995
# (DeviceArray(169964.81, dtype=float32), DeviceArray(13567.418, dtype=float32), DeviceArray(173136.66, dtype=float32), DeviceArray(3171.8376, dtype=float32))
# 996
# (DeviceArray(169723.47, dtype=float32), DeviceArray(14318.176, dtype=float32), DeviceArray(173899.4, dtype=float32), DeviceArray(4175.9375, dtype=float32))
# 997
# (DeviceArray(170140.27, dtype=float32), DeviceArray(14347.2, dtype=float32), DeviceArray(174600.27, dtype=float32), DeviceArray(4460.004, dtype=float32))
# 998
# (DeviceArray(170742.89, dtype=float32), DeviceArray(13911.767, dtype=float32), DeviceArray(170941.25, dtype=float32), DeviceArray(198.35216, dtype=float32))
# 999
# (DeviceArray(171427.6, dtype=float32), DeviceArray(13181.66, dtype=float32), DeviceArray(178374.9, dtype=float32), DeviceArray(6947.305, dtype=float32))
# 0.016968150374818854 0.028594224996703558

# %%
baseline_trials = 20
T_prev_baseline = np.ones_like(T_prev, dtype=float) * baseline_trials

probs_empirical_baseline = sample_spikes_array(probs_true_scan, T_prev_baseline, NUM_THREADS=24)

w_inits_array_baseline = np.zeros((probs_empirical_baseline.shape[0], probs_empirical_baseline.shape[1]), dtype=object)
for i in range(len(w_inits_array_baseline)):
    for j in range(len(w_inits_array_baseline[i])):
        w_inits = []

        for m in ms:
            w_init = np.array(np.random.normal(size=(m, amps_scan[j].shape[1]+1)))
            w_inits.append(w_init)

        w_inits_array_baseline[i][j] = w_inits

input_list_baseline = fitting.generate_input_list(probs_empirical_baseline, amps_scan, T_prev_baseline, w_inits_array_baseline, 1 / baseline_trials,
                                                    disambiguate=disambiguate, min_inds=min_inds)

pool = mp.Pool(processes=24)
results_baseline = pool.starmap_async(fitting.fit_surface, input_list_baseline)
mp_output_baseline = results_baseline.get()
pool.close()

params_curr_baseline = np.zeros((probs_empirical_baseline.shape[0], probs_empirical_baseline.shape[1]), dtype=object)
w_inits_array_baseline = np.zeros((probs_empirical_baseline.shape[0], probs_empirical_baseline.shape[1]), dtype=object)
probs_curr_baseline = np.zeros(probs_empirical_baseline.shape)

cnt = 0
for i in range(len(probs_empirical_baseline)):
    for j in range(len(probs_empirical_baseline[i])):
        params_curr_baseline[i][j] = mp_output_baseline[cnt][0]
        w_inits_array_baseline[i][j] = mp_output_baseline[cnt][1]
        
        probs_curr_baseline[i][j] = fitting.sigmoidND_nonlinear(
                                sm.add_constant(amps_scan[j], has_constant='add'), 
                                params_curr_baseline[i][j])

        cnt += 1

performance_baseline = get_performance_array(params_true, probs_curr_baseline, probs_true_scan)

# %%
plt.figure(figsize=(10, 8))

plt.plot(np.array(num_samples)/T_prev.shape[0]/T_prev.shape[1], performances, linewidth=4, c='tab:blue', label='Optimal Sampling')
plt.plot(np.array(num_samples_uniform)/T_prev_uniform.shape[0]/T_prev_uniform.shape[1], performances_uniform, linewidth=4, c='tab:red', label='Uniform Sampling')

plt.axhline(performance_baseline, c='k', linestyle='--', linewidth=2, label=f'{baseline_trials} Uniform Trials')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Average Trials per Current Level', fontsize=24)
plt.ylabel(r'RMSE', fontsize=24)
plt.legend(fontsize=20)

# plt.savefig(f'triplet_AL_fakedata_n120_p80.png', dpi=300)

# %%
# CHECK DATASET IF NEEDED
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(probs_true_scan)):
    for j in range(len(probs_true_scan[i])):
        if type(params_true[i][j]) != int:

            print(params_true[i][j])
            sampled_inds = np.where(T_prev[j] > 0)[0]
            
            fig = plt.figure(0)
            fig.clear()
            ax = Axes3D(fig, auto_add_to_figure=False)
            fig.add_axes(ax)
            plt.xlabel(r'$I_1$ ($\mu$A)', fontsize=16)
            plt.ylabel(r'$I_2$ ($\mu$A)', fontsize=16)
            plt.xlim(-1.8, 1.8)
            plt.ylim(-1.8, 1.8)
            ax.set_zlim(-1.8, 1.8)
            ax.set_zlabel(r'$I_3$ ($\mu$A)', fontsize=16)

            scat = ax.scatter(amps_scan[j][:, 0], 
                              amps_scan[j][:, 1],
                              amps_scan[j][:, 2], marker='o', 
                              c=probs_true_scan[i][j], s=20, alpha=0.8, vmin=0, vmax=1)
            plt.show()


            print(params_curr[i][j])
            fig = plt.figure(1)
            fig.clear()
            ax = Axes3D(fig, auto_add_to_figure=False)
            fig.add_axes(ax)
            plt.xlabel(r'$I_1$ ($\mu$A)', fontsize=16)
            plt.ylabel(r'$I_2$ ($\mu$A)', fontsize=16)
            plt.xlim(-1.8, 1.8)
            plt.ylim(-1.8, 1.8)
            ax.set_zlim(-1.8, 1.8)
            ax.set_zlabel(r'$I_3$ ($\mu$A)', fontsize=16)

            scat = ax.scatter(amps_scan[j][:, 0], 
                              amps_scan[j][:, 1],
                              amps_scan[j][:, 2], marker='o', 
                              c=probs_curr[i][j], s=20, alpha=0.8, vmin=0, vmax=1)
            plt.show()

            fig = plt.figure(1)
            fig.clear()
            ax = Axes3D(fig, auto_add_to_figure=False)
            fig.add_axes(ax)
            plt.xlabel(r'$I_1$ ($\mu$A)', fontsize=16)
            plt.ylabel(r'$I_2$ ($\mu$A)', fontsize=16)
            plt.xlim(-1.8, 1.8)
            plt.ylim(-1.8, 1.8)
            ax.set_zlim(-1.8, 1.8)
            ax.set_zlabel(r'$I_3$ ($\mu$A)', fontsize=16)

            scat = ax.scatter(amps_scan[j][sampled_inds, 0], 
                              amps_scan[j][sampled_inds, 1],
                              amps_scan[j][sampled_inds, 2], marker='o', 
                              c=probs_empirical[i][j][sampled_inds], s=20, alpha=0.8, vmin=0, vmax=1)
            plt.show()

            input()
